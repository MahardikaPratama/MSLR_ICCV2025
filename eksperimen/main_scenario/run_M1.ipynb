# %% [markdown]
# # Experiment Scenario: M1\nThis experiment executes the pipeline on the BISINDO dataset (Signer Dependent) following the instructions in PANDUAN_COLAB.md.\n**Note:** Please ensure your Google Colab runtime is set to GPU (Runtime > Change runtime type > Hardware accelerator: T4/V100/A100 GPU) before running this notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Initial Setup
# Connect your Google Drive to securely save your progress, clone the repository, and navigate to the project directory.

# %%
# Clone the repository (replace the URL if you are using your own fork)
# !git clone https://github.com/MahardikaPratama/MSLR_ICCV2025.git

# Navigate to the project directory
# %cd MSLR_ICCV2025

# Install required Python dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'MSLR_ICCV2025'...
# remote: Enumerating objects: 700, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 700 (delta 151), reused 206 (delta 113), pack-reused 440 (from 1)
# Receiving objects: 100% (700/700), 2.70 MiB | 11.94 MiB/s, done.
# Resolving deltas: 100% (402/402), done.
# /content/MSLR_ICCV2025
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy->-r requirements.txt (line 1)) (2.0.2)

# %% [markdown]
# ## 2. Install Dependencies
# Install `ctcdecode` and `sclite` for CTC decoding and alignment evaluations.

# %%
# !git clone --recursive https://github.com/WayenVan/ctcdecode.git
# %cd ctcdecode
# !pip install .
# %cd /content/MSLR_ICCV2025
# Out:
# Cloning into 'ctcdecode'...
# remote: Enumerating objects: 1400, done.
# remote: Counting objects: 100% (367/367), done.
# remote: Compressing objects: 100% (324/324), done.
# remote: Total 1400 (delta 38), reused 358 (delta 35), pack-reused 1033 (from 1)
# Receiving objects: 100% (1400/1400), 1.22 MiB | 12.48 MiB/s, done.
# Resolving deltas: 100% (532/532), done.
# /content/MSLR_ICCV2025/ctcdecode
# Processing /content/MSLR_ICCV2025/ctcdecode
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ctcdecode
#   Building wheel for ctcdecode (setup.py) ... done
#   Created wheel for ctcdecode: filename=ctcdecode-1.0.3-cp312-cp312-linux_x86_64.whl size=19610796 sha256=a3fe28ae64c24eefd3300de2b2077dd01748366c8a7f03495db18c81a8819272
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3mmx7yqo/wheels/ad/eb/a7/751fcc20462b46f21d32ff86f006593c0e3739c6184b0c04f1
# Successfully built ctcdecode
# Installing collected packages: ctcdecode
# Successfully installed ctcdecode-1.0.3
# /content/MSLR_ICCV2025

# %%
# !mkdir -p ./software
# !git clone https://github.com/usnistgov/SCTK.git
# %cd SCTK
# !make config
# !make all
# !make check
# !make install
# !make doc
# %cd ..
# !ln -s $(pwd)/SCTK/bin/sclite ./software/sclite
# Out:
# Cloning into 'SCTK'...
# remote: Enumerating objects: 5487, done.
# remote: Counting objects: 100% (344/344), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 5487 (delta 143), reused 286 (delta 117), pack-reused 5143 (from 1)
# Receiving objects: 100% (5487/5487), 7.61 MiB | 19.73 MiB/s, done.
# Resolving deltas: 100% (3827/3827), done.
# /content/MSLR_ICCV2025/SCTK
# (mkdir -p bin)
# (cd src && if test -f makefile ; then make config ; fi)
# make[1]: Entering directory '/content/MSLR_ICCV2025/SCTK/src'
# (cd asclite && if test -f makefile ; then make config ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/asclite'
# (cd core && sh config.sh -prefix=`cd ../../.. && pwd`)
# checking for g++... g++
# checking for C++ compiler default output file name... a.out
# checking whether the C++ compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking for main in -lm... yes
# checking how to run the C preprocessor... gcc -E
# checking for egrep... grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for unistd.h... (cached) yes
# checking for string.h... (cached) yes
# checking iostream usability... no
# checking iostream presence... no
# checking for iostream... no
# checking ostream usability... no
# checking ostream presence... no
# checking for ostream... no
# checking fstream usability... no
# checking fstream presence... no
# checking for fstream... no
# checking iomanip usability... no
# checking iomanip presence... no
# checking for iomanip... no
# checking map usability... no
# checking map presence... no
# checking for map... no
# checking stdio.h usability... yes
# checking stdio.h presence... yes
# checking for stdio.h... yes
# checking for stdlib.h... (cached) yes
# checking math.h usability... yes
# checking math.h presence... yes
# checking for math.h... yes
# checking time.h usability... yes
# checking time.h presence... yes
# checking for time.h... yes
# checking list usability... no
# checking list presence... no
# checking for list... no
# checking vector usability... no
# checking vector presence... no
# checking for vector... no
# checking set usability... no
# checking set presence... no
# checking for set... no
# checking assert.h usability... yes
# checking assert.h presence... yes
# checking for assert.h... yes
# checking sstream usability... no
# checking sstream presence... no
# checking for sstream... no
# checking float.h usability... yes
# checking float.h presence... yes
# checking for float.h... yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking for install... /usr/bin/install
# config.sh: creating ./config.status
# config.status: creating makefile
# (cd test && sh config.sh -prefix=`cd ../../.. && pwd`)
# checking for g++... g++
# checking for C++ compiler default output file name... a.out
# checking whether the C++ compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking for main in -lm... yes
# checking how to run the C preprocessor... gcc -E
# checking for egrep... grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for unistd.h... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking for install... /usr/bin/install
# config.sh: creating ./config.status
# config.status: creating makefile
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/asclite'
# (cd sclite && sh config.sh -prefix=`cd ../.. && pwd`)
# creating cache ./config.cache
# checking for gcc... gcc
# checking whether we are using GNU C... yes
# checking whether gcc accepts -g... yes
# checking whether make sets ${MAKE}... yes
# checking for -lm... yes
# checking how to run the C preprocessor... gcc -E
# checking whether cross-compiling... no
# checking for ANSI C header files... yes
# checking for unistd.h... yes
# checking for working const... yes
# checking for size_t... yes
# checking for install... /usr/bin/install
# Checking installation site
# updating cache ./config.cache
# creating ./config.status
# creating makefile
# (cd rfilter1 && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd csrfilt && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd chfilt && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd hamzaNorm && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd tanweenFilt && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd acomp && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd def_art && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd hubscr && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd utf_filt; sh config.sh -prefix=`cd ../.. && pwd`)
# checking for nsgmls... no
# checking for onsgmls... no
# config.sh: creating ./config.status
# config.status: creating makefile
# (cd rttmSort && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd rttmSmooth && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd rttm2ctm && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd spkr2sad && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd mergectm2rttm && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd align2html && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd md-eval && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd stm2rttm && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd stmValidator && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd rttmValidator && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd ctmValidator && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# (cd slatreport && sed -e "s:PREFIX=.*:PREFIX=`cd ../.. && pwd`:" < makefile.in > makefile)
# make[1]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src'
# (mkdir -p bin)
# (cd src && if test -f makefile ; then make all ; fi)
# make[1]: Entering directory '/content/MSLR_ICCV2025/SCTK/src'
# (cd asclite && if test -f makefile ; then make all ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/asclite'
# (cd core && if test -f makefile ; then make all ; fi)
# make[3]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/asclite/core'
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o alignedsegment.o alignedsegment.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o alignedsegmentiterator.o alignedsegmentiterator.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o alignedspeech.o alignedspeech.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o alignedspeechiterator.o alignedspeechiterator.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o aligner.o aligner.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o alignment.o alignment.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o arraylevenshteinmatrix.o arraylevenshteinmatrix.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o checker.o checker.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o compressedlevenshteinmatrix.o compressedlevenshteinmatrix.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o ctm_inputparser.o ctm_inputparser.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o ctmstmrttm_segmentor.o ctmstmrttm_segmentor.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o filter.o filter.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o graphalignedsegment.o graphalignedsegment.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o graphalignedtoken.o graphalignedtoken.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o graph_coordinate.o graph_coordinate.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o graph.o graph.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o id.o id.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o inputparser.o inputparser.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o levenshtein.o levenshtein.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o levenshteinmatrix.o levenshteinmatrix.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o linestyle_inputparser.o linestyle_inputparser.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o logger.o logger.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o main.o main.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o properties.o properties.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o rawsys_reportgenerator.o rawsys_reportgenerator.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o recording.o recording.cpp
# recording.cpp: In member function ‘void Recording::AlignGeneric()’:
# recording.cpp:446:86: warning: ‘%s’ directive writing up to 254 bytes into a region of size 212 [-Wformat-overflow=]
#   446 |                 sprintf(buffer, "Align SG %lu [%s] %lu dimensions, Difficulty: %llu (%s) ---> bt=%.3f et=%.3f",
#       |                                                                                      ^~
# ......
#   451 |                                                 buffer_size,
#       |                                                 ~~~~~~~~~~~
# recording.cpp:446:33: note: assuming directive output of 5 bytes
#   446 |                 sprintf(buffer, "Align SG %lu [%s] %lu dimensions, Difficulty: %llu (%s) ---> bt=%.3f et=%.3f",
#       |                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# recording.cpp:446:33: note: assuming directive output of 5 bytes
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output 64 or more bytes (assuming 322) into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp:509:125: warning: ‘%s’ directive writing up to 254 bytes into a region of size between 147 and 185 [-Wformat-overflow=]
#   509 |                                 sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the difficulty limit (%llu [%.2f GB])",
#       |                                                                                                                             ^~
# ......
#   512 |                                                                 buffer_size,
#       |                                                                 ~~~~~~~~~~~
# recording.cpp:509:49: note: assuming directive output of 4 bytes
#   509 |                                 sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the difficulty limit (%llu [%.2f GB])",
#       |                                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 117 and 738 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp:526:125: warning: ‘%s’ directive writing up to 254 bytes into a region of size between 147 and 185 [-Wformat-overflow=]
#   526 |                                 sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too small (%llu [%s]) regarding the min difficulty limit (%llu [%.2f GB])",
#       |                                                                                                                             ^~
# ......
#   529 |                                                                 buffer_size,
#       |                                                                 ~~~~~~~~~~~
# recording.cpp:526:49: note: assuming directive output of 4 bytes
#   526 |                                 sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too small (%llu [%s]) regarding the min difficulty limit (%llu [%.2f GB])",
#       |                                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 121 and 742 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp:543:125: warning: ‘%s’ directive writing up to 254 bytes into a region of size between 147 and 185 [-Wformat-overflow=]
#   543 |                                 sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the memory limit (%llu [%.2f GB]) and no compression have been set",
#       |                                                                                                                             ^~
# ......
#   546 |                                                                 buffer_size,
#       |                                                                 ~~~~~~~~~~~
# recording.cpp:543:49: note: directive argument in the range [0, 18446744073709551614]
#   543 |                                 sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the memory limit (%llu [%.2f GB]) and no compression have been set",
#       |                                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# recording.cpp:543:49: note: assuming directive output of 4 bytes
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 146 and 767 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp: In member function ‘void Recording::AlignHypRef()’:
# recording.cpp:680:94: warning: ‘%s’ directive writing up to 254 bytes into a region of size 212 [-Wformat-overflow=]
#   680 |                         sprintf(buffer, "Align SG %lu [%s] %lu dimensions, Difficulty: %llu (%s) ---> bt=%.3f et=%.3f",
#       |                                                                                              ^~
# ......
#   685 |                             buffer_size,
#       |                             ~~~~~~~~~~~
# recording.cpp:680:41: note: assuming directive output of 5 bytes
#   680 |                         sprintf(buffer, "Align SG %lu [%s] %lu dimensions, Difficulty: %llu (%s) ---> bt=%.3f et=%.3f",
#       |                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# recording.cpp:680:41: note: assuming directive output of 5 bytes
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output 64 or more bytes (assuming 322) into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp:743:133: warning: ‘%s’ directive writing up to 254 bytes into a region of size between 147 and 185 [-Wformat-overflow=]
#   743 |                                         sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the difficulty limit (%llu [%.2f GB])",
#       |                                                                                                                                     ^~
# ......
#   746 |                                                                         buffer_size,
#       |                                                                         ~~~~~~~~~~~
# recording.cpp:743:57: note: assuming directive output of 4 bytes
#   743 |                                         sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the difficulty limit (%llu [%.2f GB])",
#       |                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 117 and 738 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp:760:133: warning: ‘%s’ directive writing up to 254 bytes into a region of size between 147 and 185 [-Wformat-overflow=]
#   760 |                                         sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too small (%llu [%s]) regarding the min difficulty limit (%llu [%.2f GB])",
#       |                                                                                                                                     ^~
# ......
#   763 |                                                                         buffer_size,
#       |                                                                         ~~~~~~~~~~~
# recording.cpp:760:57: note: assuming directive output of 4 bytes
#   760 |                                         sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too small (%llu [%s]) regarding the min difficulty limit (%llu [%.2f GB])",
#       |                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 121 and 742 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# recording.cpp:777:133: warning: ‘%s’ directive writing up to 254 bytes into a region of size between 147 and 185 [-Wformat-overflow=]
#   777 |                                         sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the memory limit (%llu [%.2f GB]) and no compression have been set",
#       |                                                                                                                                     ^~
# ......
#   780 |                                                                         buffer_size,
#       |                                                                         ~~~~~~~~~~~
# recording.cpp:777:57: note: directive argument in the range [0, 18446744073709551614]
#   777 |                                         sprintf(buffer, "Skip this group of segments (%lu): the graph size will be too large (%llu [%s]) regarding the memory limit (%llu [%.2f GB]) and no compression have been set",
#       |                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# recording.cpp:777:57: note: assuming directive output of 4 bytes
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from recording.h:21,
#                  from recording.cpp:24:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 146 and 767 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o reportgenerator.o reportgenerator.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o rttm_inputparser.o rttm_inputparser.cpp
# rttm_inputparser.cpp: In member function ‘SpeechSet* RTTMInputParser::loadFileSpeaker(const string&)’:
# rttm_inputparser.cpp:348:87: warning: ‘%s’ directive writing up to 254 bytes into a region of size 226 [-Wformat-overflow=]
#   348 |                                         sprintf(buffer, "No Segment found for speaker %s at line %li", l_spkr, lineNum);
#       |                                                                                       ^~               ~~~~~~
# rttm_inputparser.cpp:348:57: note: directive argument in the range [0, 9223372036854775807]
#   348 |                                         sprintf(buffer, "No Segment found for speaker %s at line %li", l_spkr, lineNum);
#       |                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from /usr/include/c++/11/cstdio:42,
#                  from /usr/include/c++/11/ext/string_conversions.h:43,
#                  from /usr/include/c++/11/bits/basic_string.h:6608,
#                  from /usr/include/c++/11/string:55,
#                  from /usr/include/c++/11/bits/locale_classes.h:40,
#                  from /usr/include/c++/11/bits/ios_base.h:41,
#                  from /usr/include/c++/11/ios:42,
#                  from /usr/include/c++/11/ostream:38,
#                  from /usr/include/c++/11/iostream:39,
#                  from stdinc.h:22,
#                  from inputparser.h:21,
#                  from linestyle_inputparser.h:21,
#                  from rttm_inputparser.h:21,
#                  from rttm_inputparser.cpp:22:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:34: note: ‘__builtin___sprintf_chk’ output between 40 and 312 bytes into a destination of size 255
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o scorer.o scorer.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o segment.o segment.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o segmentor.o segmentor.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o segmentsgroup.o segmentsgroup.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o sgml_generic_reportgenerator.o sgml_generic_reportgenerator.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o sgml_reportgenerator.o sgml_reportgenerator.cpp
# g++ -c  -DPACKAGE_NAME=\"\" -DPACKAGE_TARNAME=\"\" -DPACKAGE_VERSION=\"\" -DPACKAGE_STRING=\"\" -DPACKAGE_BUGREPORT=\"\" -DHAVE_LIBM=1 -DSTDC_HEADERS=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_MEMORY_H=1 -DHAVE_STRINGS_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_UNISTD_H=1 -DHAVE_UNISTD_H=1 -DHAVE_STRING_H=1 -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_MATH_H=1 -DHAVE_TIME_H=1 -DHAVE_ASSERT_H=1 -DHAVE_FLOAT_H=1 -DHAVE_LIMITS_H=1  -I.  -g -Os -o speakermatch.o speakermatch.cpp
# ...
# Testing test24.rttm...
# Testing test25.rttm...
# Testing test26.rttm...
# Testing test27.rttm...
# Testing test28.rttm...
# Testing test29.rttm...
# (skipping) Testing test30.rttm...
# (skipping) Testing test31.rttm...
# Testing test32.rttm...
# Testing test33.rttm...
# (skipping) Testing test34.rttm...
# (skipping) Testing test35.rttm...
# Testing test36.rttm...
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/rttmValidator'
# (cd ctmValidator && make check)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/ctmValidator'
# (cd test_suite; /bin/sh RunTest.sh ../ctmValidator.pl)
# Testing test00.ctm...
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/ctmValidator'
# (cd slatreport && make check)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/slatreport'
# Testing slatreport.pl
# ./slatTest.pl
# Slat Test OK.
#    slatreport.pl tests successfully completed
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/slatreport'
# (cd sclite && if test -f makefile ; then make check ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/sclite'
# ./sctkUnit
# Testing ASCII data
#   X = /TOO/
#   Y = /is/
#   A = /cd/
#   EMP = //
#   XbAbY = /TOO cd is/
#   oXhoboAoboYo = /(TOO-) (cd) (is)/
#   eqXbYeq = /\"TOO is\"/
#   X1bX2bX3 = /T O O/
#   Y1bY2 = /i s/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
# Warning: Alternates in reference texts removed in favor of the first alternate.
#
# Testing Extended ASCII data
#   X = /���/
#   Y = /��/
#   A = /cd/
#   EMP = //
#   XbAbY = /��� cd ��/
#   oXhoboAoboYo = /(���-) (cd) (��)/
#   eqXbYeq = /\"��� ��\"/
#   X1bX2bX3 = /� � �/
#   Y1bY2 = /� �/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
#
# Testing 2-byte UTF-8 data
#   X = /αχρ/
#   Y = /μφ/
#   A = /cd/
#   EMP = //
#   XbAbY = /αχρ cd μφ/
#   oXhoboAoboYo = /(αχρ-) (cd) (μφ)/
#   eqXbYeq = /\"αχρ μφ\"/
#   X1bX2bX3 = /α χ ρ/
#   Y1bY2 = /μ φ/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
# Testing UTF Code point computation and reversal
#
# Testing 3-byte UTF-8 data
#   X = /ᎠᎪᎫ/
#   Y = /ᏋᏞ/
#   A = /cd/
#   EMP = //
#   XbAbY = /ᎠᎪᎫ cd ᏋᏞ/
#   oXhoboAoboYo = /(ᎠᎪᎫ-) (cd) (ᏋᏞ)/
#   eqXbYeq = /\"ᎠᎪᎫ ᏋᏞ\"/
#   X1bX2bX3 = /Ꭰ Ꭺ Ꭻ/
#   Y1bY2 = /Ꮛ Ꮮ/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
# Testing UTF Code point computation and reversal
#
# Testing 4-byte UTF-8 data
#   X = /𐅀𐅃𐅁/
#   Y = /𐅼𐆐/
#   A = /cd/
#   EMP = //
#   XbAbY = /𐅀𐅃𐅁 cd 𐅼𐆐/
#   oXhoboAoboYo = /(𐅀𐅃𐅁-) (cd) (𐅼𐆐)/
#   eqXbYeq = /\"𐅀𐅃𐅁 𐅼𐆐\"/
#   X1bX2bX3 = /𐅀 𐅃 𐅁/
#   Y1bY2 = /𐅼 𐆐/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
# Testing UTF Code point computation and reversal
#
# Testing 2-byte GB data
#   X = /�Զ���/
#   Y = /����/
#   A = /cd/
#   EMP = //
#   XbAbY = /�Զ��� cd ����/
#   oXhoboAoboYo = /(�Զ���-) (cd) (����)/
#   eqXbYeq = /\"�Զ��� ����\"/
#   X1bX2bX3 = /�� �� ��/
#   Y1bY2 = /�� ��/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
#
# Testing ASCII as UTF-8 data
#   X = /TOO/
#   Y = /is/
#   A = /cd/
#   EMP = //
#   XbAbY = /TOO cd is/
#   oXhoboAoboYo = /(TOO-) (cd) (is)/
#   eqXbYeq = /\"TOO is\"/
#   X1bX2bX3 = /T O O/
#   Y1bY2 = /i s/
#   A1bA2 = /c d/
#   A1bA2 = /c d/
# Testing UTF Code point computation and reversal
#
# Testing Case Conversion for Babel Turkish
# UC /ÇÖÜİI/, LC /çöüiı/
# UC /III/, LC /ııı/
# Total Tests: 1178
# Errors: 0
# cd testdata && ./tsclite.sh
# tsclite.sh -- Version 1.2
# Variables:
#     reference directory  = base
#     executable directory = ..
#     sclite executable    = sclite
#     Diff Alignments Disabled
#     SLM-Toolkit Disabled
#
# test1: Align Both Ref and Hyp transcripts. (one transcript to a line followed by an utterance id in parens)
# test1a: Same as test1, but generating an sgml file, then piping to sclite for reports
# test1b: Same as test1, but using a language model for weights
#             **** SLM weighted alignment is disabled, not testing ***
# test1c: Same as test1, but using a language model for weights
# test1d: Same as test1, but producing a nl.sgml file
# test1e: Same as test1 but with utf-8 1 bytes per char
# test2: Same as Test 1, but use Diff instead of DP alignments
#             **** Diff alignments have been disabled, not testing ***
# test3: Align Segmental Time marks (STM) to Conversation time marks (CTM)
# test3a: Align Segmental Time marks (STM) to Conversation time marks (CTM) using the stm tag IGNORE_TIME_SEGMENT_IN_SCORING
# test3b: Align Segmental Time marks (STM) to Conversation time marks (CTM) with confidence scores
# test3c: Test the output generated in lur when ther is no reference data
# Test 4:     Same as test 3, but using diff for alignment
#             **** Diff alignments have been disabled, not testing ***
# Test 5:     Align STM to free formatted text (TXT)
#             **** Diff alignments have been disabled, not testing ***
# Test 6:     Align Mandarin Chinese words using DIFF
#             **** Diff alignments have been disabled, not testing ***
# Test 7:     Run some test cases through
# Test 7_r:   Run some test cases through (reversing ref and hyp)
# Test 7_noD:   Run some test cases through (reversing ref and hyp)
# Test 7_1:   Run some test cases through using infered word boundaries,
#             not changing ASCII words
# Test 7_2:   Run some test cases through using infered word boundaries,
#             changing ASCII words
# Test 7_2a:  Run some test cases through using infered word boundaries,
#             changing ASCII words, using algo2.
# Test 7_3:   Run some test cases through using infered word boundaries,
#             not changing ASCII words and correct Fragments
# Test 7_4:   Run some test cases through using infered word boundaries,
#             changing ASCII words and correct Fragments
# Test 7_5:   Run some test cases through, character aligning them and
#             removing hyphens
# Test 7_6:     Run some test cases through with utf-8 encoding
# test7-utf8-2bytes: Same as test 1 but with utf8-2bytes
# test7-utf8-3bytes: Same as test 1 but with utf8-3bytes
# test7-utf8-4bytes: Same as test 1 but with utf8-4bytes
# Test 8:     Align transcripts as character alignments
# Test 9:     Run the Mandarin, doing a character alignment
# Test 9_1:   Run the Mandarin, doing a character alignment, removing hyphens
# Test 10:    Run the Mandarin, doing a character alignment, not effecting ASCII WORDS
# ../sclite -e gb -r ./mand_ref.stm stm -h ./mand_hyp.ctm ctm -o all prf -O out -f 0 -n test10 -c NOASCII
# Test 10_1:  Run the Mandarin, doing a character alignment, not effecting ASCII WORDS
#             Removing hyphens.
# Test 11:    Run the Mandarin, doing the inferred word segmentation alignments, algo1
# Test 12:    Run the Mandarin, doing the inferred word segmentation alignments, algo1
#             Scoring fragments as correct
# Test 13:    Run alignments on two CTM files, using DP Word alignments
# Test 13_D:    Run alignments on two CTM files, using DP Word alignments
# Test 13_a:  Run alignments on two CTM files, using Time-Mediated DP alignments
# Test 13_aD:  Run alignments on two CTM files, using Time-Mediated DP alignments
# Test 14_a:  Reduce the ref and hyp input files to the intersection of the inputs
# Test 14_b:  Reduce the ref and hyp input files to the intersection of the inputs
#             Using a reduced size hyp file
# Test 14_c:  Reduce the ref and hyp input files to the intersection of the inputs
#             Using a reduced size hyp file
# Test 14_d:  Reduce the ref and hyp input files to the intersection of the inputs
#             Using a reduced size hyp and ref file
# Test 14_e:  Reduce the ref and hyp input files to the intersection of the inputs
#             Using a reduced size hyp and ref file
# test15_a: UTF-8 test - Cantonese no options
# test15_b: UTF-8 test - Cantonese no options - Character scoring
# test15_c: UTF-8 test - UTF-8 Turkish
# test15_d: UTF-8 test - UTF-8 Ukranian
# test16_1: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-extra.ctm
# test16_2: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missall.ctm
# test16_3: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missfile1.ctm
# test16_4: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missfile1chanA.ctm
# test16_5: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missfile1chanb.ctm
# test16_6: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missfile2.ctm
# test16_7: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missfile2chanA.ctm
# test16_8: Allow incomplete hyp CTM files - stm2ctm_missing.hyp-missfile2chanB.ctm
# test16_9: Allow incomplete hyp CTM files - stm2ctm_missing.hyp.ctm
# test17: Vietnamese case conversion
#
# Executions complete: Comparing output
#    Removing DIFF tests
#    Removing SLM tests
#
# ALL TESTS SUCCESSFULLY COMPLETED
# cd testdata && ./tsc_stats.sh
# tsc_stats.sh -- Version 1.0
# Variables:
#     reference directory  = base_sc_stats
#     executable directory = ..
#     sc_stats executable    = sc_stats
#
# Test 1a+1b:     Symmetric tests on MAPSSWE
#
# Executions complete: Comparing output
#
# ALL TESTS SUCCESSFULLY COMPLETED
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/sclite'
# make[1]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src'
# (mkdir -p bin)
# (cd src && if test -f makefile ; then make install ; fi)
# make[1]: Entering directory '/content/MSLR_ICCV2025/SCTK/src'
# (cd asclite && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/asclite'
# (cd core && if test -f makefile ; then make install ; fi)
# make[3]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/asclite/core'
# for p in asclite; do \
# 	/usr/bin/install $p /content/MSLR_ICCV2025/SCTK/bin/$p; \
# done
# make[3]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/asclite/core'
# (cd test && if test -f makefile ; then make install ; fi)
# make[3]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/asclite/test'
# make[3]: Nothing to be done for 'install'.
# make[3]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/asclite/test'
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/asclite'
# (cd sclite && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/sclite'
# Error: directory /content/MSLR_ICCV2025/SCTK/man/man1 doesn't exist
# Error: directory /content/MSLR_ICCV2025/SCTK/man/man5 doesn't exist
# set -e; for p in sclite sc_stats rover sctkUnit; do \
#   /usr/bin/install $p /content/MSLR_ICCV2025/SCTK/bin/$p; \
# done
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/sclite'
# (cd rfilter1 && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/rfilter1'
# install rfilter1 /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/rfilter1'
# (cd csrfilt && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/csrfilt'
# cp csrfilt.sh /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/csrfilt'
# (cd chfilt && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/chfilt'
# cp chfilt.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/chfilt'
# (cd hamzaNorm && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/hamzaNorm'
# cp hamzaNorm.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/hamzaNorm'
# (cd tanweenFilt && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/tanweenFilt'
# cp tanweenFilt.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/tanweenFilt'
# (cd acomp && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/acomp'
# cp acomp.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/acomp'
# (cd def_art && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/def_art'
# cp def_art.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/def_art'
# (cd hubscr && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/hubscr'
# cp hubscr.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/hubscr'
# (cd utf_filt && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/utf_filt'
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/utf_filt'
# (cd rttmSort && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/rttmSort'
# cp rttmSort.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/rttmSort'
# (cd rttm2ctm && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/rttm2ctm'
# cp rttm2ctm.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/rttm2ctm'
# (cd rttmSmooth && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/rttmSmooth'
# cp rttmSmooth.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/rttmSmooth'
# (cd spkr2sad && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/spkr2sad'
# cp spkr2sad.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/spkr2sad'
# (cd mergectm2rttm && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/mergectm2rttm'
# cp mergectm2rttm.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/mergectm2rttm'
# (cd align2html && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/align2html'
# perl buildInstallVersion.pl > /content/MSLR_ICCV2025/SCTK/bin/align2html.pl
# chmod +x /content/MSLR_ICCV2025/SCTK/bin/align2html.pl
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/align2html'
# (cd md-eval && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/md-eval'
# cp md-eval.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/md-eval'
# (cd stm2rttm && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/stm2rttm'
# cp stm2rttm.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/stm2rttm'
# (cd stmValidator && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/stmValidator'
# perl buildInstallVersion.pl > stmValidator.pl
# chmod +x stmValidator.pl
# perl buildInstallVersion.pl > /content/MSLR_ICCV2025/SCTK/bin/stmValidator.pl
# chmod +x /content/MSLR_ICCV2025/SCTK/bin/stmValidator.pl
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/stmValidator'
# (cd rttmValidator && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/rttmValidator'
# cp rttmValidator.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/rttmValidator'
# (cd ctmValidator && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/ctmValidator'
# cp ctmValidator.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/ctmValidator'
# (cd slatreport && if test -f makefile ; then make install ; fi)
# make[2]: Entering directory '/content/MSLR_ICCV2025/SCTK/src/slatreport'
# cp slatreport.pl /content/MSLR_ICCV2025/SCTK/bin
# make[2]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src/slatreport'
# make[1]: Leaving directory '/content/MSLR_ICCV2025/SCTK/src'
# (cd doc && if test -f makefile ; then make all ; fi)
# make[1]: Entering directory '/content/MSLR_ICCV2025/SCTK/doc'
# for p in align2html asclite ctmValidator mergectm2rttm; do \
# 	pod2man $p.pod -o $p.1; \
# 	pod2html $p.pod > $p.html; \
# done 2> /dev/null
# make[1]: Leaving directory '/content/MSLR_ICCV2025/SCTK/doc'
# /content/MSLR_ICCV2025

# %% [markdown]
# ## 3. Dataset Preparation
# Download the BISINDO dataset using `gdown` and run the preprocessing script.

# %%
# !pip install gdown
# !mkdir -p ./datasets/mslr2025

# Download the complete dataset from the Google Drive Folder
# !gdown --folder "1jxAJ7VIvrL2X4WpvqhDdmZH6lUXGQrnF" -O ./datasets_temp
# !mv ./datasets_temp/* ./datasets/mslr2025/
# !rm -rf ./datasets_temp
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Retrieving folder contents
# Processing file 1t-X50HyQdfww7cujFUVkWuZ08G-LyFAw pose_bisindo_test_sd.pkl
# Processing file 1aTFMrb5Pu4SmqvAXPJloKpd5TiWva5HV pose_bisindo_test_si-maj.pkl
# Processing file 1q-dv8Iy5jxabd6hY4MPbjCMmQ4jo53nx pose_bisindo_test_si-min.pkl
# Processing file 13u5wgL4tbDuO4ZI-9OidcrvZT1xYTNIF pose_bisindo_train_dev_sd.pkl
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1t-X50HyQdfww7cujFUVkWuZ08G-LyFAw
# To: /content/MSLR_ICCV2025/datasets_temp/pose_bisindo_test_sd.pkl
# 100% 42.4M/42.4M [00:00<00:00, 47.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1aTFMrb5Pu4SmqvAXPJloKpd5TiWva5HV
# To: /content/MSLR_ICCV2025/datasets_temp/pose_bisindo_test_si-maj.pkl
# 100% 7.73M/7.73M [00:00<00:00, 20.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1q-dv8Iy5jxabd6hY4MPbjCMmQ4jo53nx
# To: /content/MSLR_ICCV2025/datasets_temp/pose_bisindo_test_si-min.pkl
# 100% 8.81M/8.81M [00:00<00:00, 40.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=13u5wgL4tbDuO4ZI-9OidcrvZT1xYTNIF
# From (redirected): https://drive.google.com/uc?id=13u5wgL4tbDuO4ZI-9OidcrvZT1xYTNIF&confirm=t&uuid=ccceb3c3-419c-44e5-97ac-f64087f45d70
# To: /content/MSLR_ICCV2025/datasets_temp/pose_bisindo_train_dev_sd.pkl
# 100% 169M/169M [00:02<00:00, 63.8MB/s]
# Download completed

# %%
# %cd preprocess/mslr2025
# !python mslr_process.py
# %cd ../../
# Out:
# /content/MSLR_ICCV2025/preprocess/mslr2025
#
# ===================================
# MSLR2025 PREPROCESSING START
# ===================================
#
#
# Processing: train
# 100% 450/450 [00:00<00:00, 436401.57it/s]
# train completed (450 samples)
#
# Processing: dev
# 100% 150/150 [00:00<00:00, 442748.49it/s]
# dev completed (150 samples)
#
# Processing: test_sd
# 100% 150/150 [00:00<00:00, 603786.56it/s]
# test_sd completed (150 samples)
#
# Processing: test_si_major
# 100% 30/30 [00:00<00:00, 432402.47it/s]
# test_si_major completed (30 samples)
#
# Processing: test_si_minor
# 100% 30/30 [00:00<00:00, 334651.91it/s]
# test_si_minor completed (30 samples)
#
# ===================================
# PREPROCESSING FINISHED
# ===================================
#
# Total gloss vocabulary : 93
# Gloss dictionary saved at:
# /content/MSLR_ICCV2025/datasets/mslr2025/global_gloss_dict.json
#
# All preprocessing completed.
#
# /content/MSLR_ICCV2025

# %% [markdown]
# ## 4. Training Process
# Ensure you have configured the data augmentation strategy in `datasets/skeleton_feeder.py` (around line 194) before proceeding.
# Run the cell below to start training for the Signer Dependent task:

# %%
# !python main.py --config ./configs/experiment_configs/main_scenario/M1.yaml
# Out:
# Loading model
# Loading model finished.
# Loading data
# Apply training transform: []
# [SkeletonFeeder] Normalization pipeline: ['spatial']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# [SkeletonFeeder][train] data_before=450 data_after=450 frames_before=92654 frames_after=46229
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['spatial']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# [SkeletonFeeder][dev] data_before=150 data_after=150 frames_before=29849 frames_after=14890
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['spatial']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# [SkeletonFeeder][test_sd] data_before=150 data_after=150 frames_before=30780 frames_after=15358
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['spatial']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# [SkeletonFeeder][test_si_major] data_before=30 data_after=30 frames_before=5618 frames_after=2802
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['spatial']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# [SkeletonFeeder][test_si_minor] data_before=30 data_after=30 frames_before=6400 frames_after=3194
# Loading data finished.
# [ Mon Jun  1 01:40:01 2026 ] Parameters:
# {'work_dir': './work_dir/Baseline+SN/', 'google_drive_dir': '/content/drive/MyDrive/MSLR_RESULTS', 'config': './configs/experiment_configs/normalization/Baseline+SN.yaml', 'random_fix': True, 'device': 0, 'processor': None, 'phase': 'train', 'train_args': {}, 'save_interval': 1, 'random_seed': 123, 'eval_interval': 1, 'print_log': True, 'log_interval': 100, 'evaluate_tool': 'sclite', 'feeder': 'SkeletonFeeder', 'dataset': 'bisindo', 'num_worker': 2, 'feeder_args': {'setting': 'sd', 'datatype': 'skeleton', 'split': [21, 42], 'norm_point': [0, 21], 'used_part': ['left_hand', 'right_hand'], 'augmentation_types': [], 'normalization_types': ['spatial'], 'downsampling': True, 'downsampling_ratio': 0.5, 'mode': 'test_si_minor', 'transform_mode': False, 'dataset': 'bisindo', 'dataset_root': './datasets/mslr2025'}, 'model': 'TwoStream_Cosign', 'model_args': {'visual_args': {'in_channels': 2, 'split': [21, 42], 'temporal_kernel': 5, 'hidden_size': 1024, 'modes': ['left_hand', 'right_hand'], 'level': '1', 'adaptive': True, 'CR_args': {'clip_length': 25, 'ratio': 0.2}}, 'conv_type': 'K3-P2-K3-P2', 'loss_weights': {'CR_ConvCTC_static': 1.0, 'CR_SeqCTC_static': 1.0, 'CR_Conv_static': 2.0, 'CR_Seq_static': 2.0, 'CR_ConvCTC_motion': 1.0, 'CR_SeqCTC_motion': 1.0, 'CR_Conv_motion': 2.0, 'CR_Seq_motion': 2.0, 'CR_ConvCTC_fusion': 1.0, 'CR_SeqCTC_fusion': 1.0, 'CR_Conv_fusion': 2.0, 'CR_Seq_fusion': 2.0}, 'norm_scale': 32}, 'load_weights': None, 'load_checkpoints': None, 'ignore_weights': [], 'batch_size': 8, 'test_batch_size': 8, 'optimizer_args': {'base_lr': 0.0004, 'learning_ratio': 1, 'nesterov': False, 'optimizer': 'AdamW', 'start_epoch': 0, 'step': [20, 35], 'weight_decay': 0.0001}, 'num_epoch': 40, 'dataset_info': {'dataset_root': './datasets/mslr2025', 'dict_path': './datasets/mslr2025/global_gloss_dict.json', 'evaluation_dir': './datasets/mslr2025', 'evaluation_prefix': 'mslr-groundtruth'}}
#
# [ Mon Jun  1 01:40:04 2026 ] 	Epoch: 0, Batch(0/56) done. Loss: 594.72  lr:0.000400
# [ Mon Jun  1 01:40:04 2026 ] 	CR_ConvCTC_static: 94.56, CR_SeqCTC_static: 94.83, CR_Conv_static: 0.95, CR_Seq_static: 0.52, CR_ConvCTC_motion: 97.67, CR_SeqCTC_motion: 104.83, CR_Conv_motion: 0.22, CR_Seq_motion: 0.35, CR_ConvCTC_fusion: 101.96, CR_SeqCTC_fusion: 97.89, CR_Conv_fusion: 0.46, CR_Seq_fusion: 0.47
# 100% 56/56 [00:51<00:00,  1.08it/s]
# [ Mon Jun  1 01:40:53 2026 ] 	Mean training loss: 257.6844817570.
# [ Mon Jun  1 01:40:53 2026 ] 	Epoch 0 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.93it/s]
# [ Mon Jun  1 01:40:58 2026 ] [DEV EVAL] Total Inference Time: 4.63s
# [ Mon Jun  1 01:40:58 2026 ] [DEV EVAL] Inference Speed: 3656.24 Frames/s, 32.42 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:40:58 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:40:58 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:40:58 2026 ] [DEV] Conv1D temporal WER:  99.90%, BiLSTM contextual WER:  96.10%
# [ Mon Jun  1 01:40:58 2026 ] Dev WER: 96.10%
# [ Mon Jun  1 01:40:59 2026 ] 	Epoch: 1, Batch(0/56) done. Loss: 207.85  lr:0.000400
# [ Mon Jun  1 01:40:59 2026 ] 	CR_ConvCTC_static: 58.44, CR_SeqCTC_static: 21.43, CR_Conv_static: 3.76, CR_Seq_static: 0.02, CR_ConvCTC_motion: 39.68, CR_SeqCTC_motion: 23.77, CR_Conv_motion: 1.32, CR_Seq_motion: 0.02, CR_ConvCTC_fusion: 34.61, CR_SeqCTC_fusion: 23.72, CR_Conv_fusion: 1.08, CR_Seq_fusion: 0.01
# 100% 56/56 [00:51<00:00,  1.09it/s]
# [ Mon Jun  1 01:41:50 2026 ] 	Mean training loss: 182.5309317453.
# [ Mon Jun  1 01:41:50 2026 ] 	Epoch 1 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.82it/s]
# [ Mon Jun  1 01:41:55 2026 ] [DEV EVAL] Total Inference Time: 4.77s
# [ Mon Jun  1 01:41:55 2026 ] [DEV EVAL] Inference Speed: 3547.58 Frames/s, 31.46 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:41:55 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:41:55 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:41:55 2026 ] [DEV] Conv1D temporal WER:  98.30%, BiLSTM contextual WER:  93.10%
# [ Mon Jun  1 01:41:55 2026 ] Dev WER: 93.10%
# [ Mon Jun  1 01:41:56 2026 ] 	Epoch: 2, Batch(0/56) done. Loss: 160.20  lr:0.000400
# [ Mon Jun  1 01:41:56 2026 ] 	CR_ConvCTC_static: 51.78, CR_SeqCTC_static: 17.35, CR_Conv_static: 3.55, CR_Seq_static: 0.01, CR_ConvCTC_motion: 26.04, CR_SeqCTC_motion: 18.55, CR_Conv_motion: 0.62, CR_Seq_motion: 0.01, CR_ConvCTC_fusion: 23.02, CR_SeqCTC_fusion: 18.78, CR_Conv_fusion: 0.49, CR_Seq_fusion: 0.01
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:42:48 2026 ] 	Mean training loss: 176.8651749747.
# [ Mon Jun  1 01:42:48 2026 ] 	Epoch 2 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.02it/s]
# [ Mon Jun  1 01:42:53 2026 ] [DEV EVAL] Total Inference Time: 4.51s
# [ Mon Jun  1 01:42:53 2026 ] [DEV EVAL] Inference Speed: 3754.29 Frames/s, 33.29 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:42:53 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:42:53 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:42:53 2026 ] [DEV] Conv1D temporal WER:  95.10%, BiLSTM contextual WER:  93.00%
# [ Mon Jun  1 01:42:53 2026 ] Dev WER: 93.00%
# [ Mon Jun  1 01:42:54 2026 ] 	Epoch: 3, Batch(0/56) done. Loss: 163.59  lr:0.000400
# [ Mon Jun  1 01:42:54 2026 ] 	CR_ConvCTC_static: 51.04, CR_SeqCTC_static: 18.04, CR_Conv_static: 2.88, CR_Seq_static: 0.11, CR_ConvCTC_motion: 26.73, CR_SeqCTC_motion: 17.93, CR_Conv_motion: 1.25, CR_Seq_motion: 0.02, CR_ConvCTC_fusion: 26.18, CR_SeqCTC_fusion: 18.55, CR_Conv_fusion: 0.85, CR_Seq_fusion: 0.02
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:43:47 2026 ] 	Mean training loss: 175.7009201050.
# [ Mon Jun  1 01:43:47 2026 ] 	Epoch 3 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.03it/s]
# [ Mon Jun  1 01:43:52 2026 ] [DEV EVAL] Total Inference Time: 4.53s
# [ Mon Jun  1 01:43:52 2026 ] [DEV EVAL] Inference Speed: 3736.54 Frames/s, 33.13 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:43:52 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:43:52 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:43:52 2026 ] [DEV] Conv1D temporal WER:  97.30%, BiLSTM contextual WER:  91.70%
# [ Mon Jun  1 01:43:52 2026 ] Dev WER: 91.70%
# [ Mon Jun  1 01:43:53 2026 ] 	Epoch: 4, Batch(0/56) done. Loss: 176.01  lr:0.000400
# [ Mon Jun  1 01:43:53 2026 ] 	CR_ConvCTC_static: 61.87, CR_SeqCTC_static: 19.41, CR_Conv_static: 1.65, CR_Seq_static: 0.02, CR_ConvCTC_motion: 24.71, CR_SeqCTC_motion: 20.64, CR_Conv_motion: 0.46, CR_Seq_motion: 0.02, CR_ConvCTC_fusion: 26.44, CR_SeqCTC_fusion: 20.07, CR_Conv_fusion: 0.70, CR_Seq_fusion: 0.02
# 100% 56/56 [00:52<00:00,  1.06it/s]
# [ Mon Jun  1 01:44:45 2026 ] 	Mean training loss: 169.5668642862.
# [ Mon Jun  1 01:44:45 2026 ] 	Epoch 4 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.99it/s]
# [ Mon Jun  1 01:44:50 2026 ] [DEV EVAL] Total Inference Time: 4.56s
# [ Mon Jun  1 01:44:50 2026 ] [DEV EVAL] Inference Speed: 3707.74 Frames/s, 32.88 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:44:50 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:44:50 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:44:50 2026 ] [DEV] Conv1D temporal WER:  99.00%, BiLSTM contextual WER:  88.40%
# [ Mon Jun  1 01:44:50 2026 ] Dev WER: 88.40%
# [ Mon Jun  1 01:44:51 2026 ] 	Epoch: 5, Batch(0/56) done. Loss: 160.47  lr:0.000400
# [ Mon Jun  1 01:44:51 2026 ] 	CR_ConvCTC_static: 59.40, CR_SeqCTC_static: 17.17, CR_Conv_static: 2.44, CR_Seq_static: 0.01, CR_ConvCTC_motion: 23.22, CR_SeqCTC_motion: 17.67, CR_Conv_motion: 0.41, CR_Seq_motion: 0.01, CR_ConvCTC_fusion: 22.51, CR_SeqCTC_fusion: 17.37, CR_Conv_fusion: 0.24, CR_Seq_fusion: 0.02
# 100% 56/56 [00:52<00:00,  1.06it/s]
# [ Mon Jun  1 01:45:42 2026 ] 	Mean training loss: 164.0471303122.
# [ Mon Jun  1 01:45:42 2026 ] 	Epoch 5 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.79it/s]
# [ Mon Jun  1 01:45:48 2026 ] [DEV EVAL] Total Inference Time: 4.79s
# [ Mon Jun  1 01:45:48 2026 ] [DEV EVAL] Inference Speed: 3528.07 Frames/s, 31.28 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:45:48 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:45:48 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:45:48 2026 ] [DEV] Conv1D temporal WER:  98.70%, BiLSTM contextual WER:  89.20%
# [ Mon Jun  1 01:45:48 2026 ] Dev WER: 89.20%
# [ Mon Jun  1 01:45:49 2026 ] 	Epoch: 6, Batch(0/56) done. Loss: 171.75  lr:0.000400
# [ Mon Jun  1 01:45:49 2026 ] 	CR_ConvCTC_static: 73.28, CR_SeqCTC_static: 15.58, CR_Conv_static: 2.12, CR_Seq_static: 0.01, CR_ConvCTC_motion: 23.81, CR_SeqCTC_motion: 15.40, CR_Conv_motion: 0.71, CR_Seq_motion: 0.03, CR_ConvCTC_fusion: 24.91, CR_SeqCTC_fusion: 15.11, CR_Conv_fusion: 0.78, CR_Seq_fusion: 0.03
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:46:41 2026 ] 	Mean training loss: 162.1333443778.
# [ Mon Jun  1 01:46:41 2026 ] 	Epoch 6 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.95it/s]
# [ Mon Jun  1 01:46:46 2026 ] [DEV EVAL] Total Inference Time: 4.58s
# [ Mon Jun  1 01:46:46 2026 ] [DEV EVAL] Inference Speed: 3692.81 Frames/s, 32.75 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:46:46 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:46:46 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:46:46 2026 ] [DEV] Conv1D temporal WER:  100.00%, BiLSTM contextual WER:  90.20%
# [ Mon Jun  1 01:46:46 2026 ] Dev WER: 90.20%
# [ Mon Jun  1 01:46:47 2026 ] 	Epoch: 7, Batch(0/56) done. Loss: 151.65  lr:0.000400
# [ Mon Jun  1 01:46:47 2026 ] 	CR_ConvCTC_static: 53.50, CR_SeqCTC_static: 17.12, CR_Conv_static: 1.16, CR_Seq_static: 0.00, CR_ConvCTC_motion: 24.85, CR_SeqCTC_motion: 14.61, CR_Conv_motion: 0.72, CR_Seq_motion: 0.03, CR_ConvCTC_fusion: 23.81, CR_SeqCTC_fusion: 15.26, CR_Conv_fusion: 0.55, CR_Seq_fusion: 0.04
# 100% 56/56 [00:54<00:00,  1.04it/s]
# [ Mon Jun  1 01:47:40 2026 ] 	Mean training loss: 161.4730170114.
# [ Mon Jun  1 01:47:40 2026 ] 	Epoch 7 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.01it/s]
# [ Mon Jun  1 01:47:45 2026 ] [DEV EVAL] Total Inference Time: 4.55s
# [ Mon Jun  1 01:47:45 2026 ] [DEV EVAL] Inference Speed: 3721.83 Frames/s, 33.00 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:47:45 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:47:45 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:47:45 2026 ] [DEV] Conv1D temporal WER:  94.40%, BiLSTM contextual WER:  87.00%
# [ Mon Jun  1 01:47:45 2026 ] Dev WER: 87.00%
# [ Mon Jun  1 01:47:46 2026 ] 	Epoch: 8, Batch(0/56) done. Loss: 180.41  lr:0.000400
# [ Mon Jun  1 01:47:46 2026 ] 	CR_ConvCTC_static: 64.46, CR_SeqCTC_static: 18.76, CR_Conv_static: 1.71, CR_Seq_static: 0.00, CR_ConvCTC_motion: 30.38, CR_SeqCTC_motion: 18.52, CR_Conv_motion: 0.66, CR_Seq_motion: 0.04, CR_ConvCTC_fusion: 26.98, CR_SeqCTC_fusion: 18.41, CR_Conv_fusion: 0.48, CR_Seq_fusion: 0.02
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 01:48:39 2026 ] 	Mean training loss: 159.9647169113.
# [ Mon Jun  1 01:48:39 2026 ] 	Epoch 8 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.83it/s]
# [ Mon Jun  1 01:48:44 2026 ] [DEV EVAL] Total Inference Time: 4.74s
# [ Mon Jun  1 01:48:44 2026 ] [DEV EVAL] Inference Speed: 3570.55 Frames/s, 31.66 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:48:44 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:48:44 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:48:44 2026 ] [DEV] Conv1D temporal WER:  95.70%, BiLSTM contextual WER:  91.30%
# [ Mon Jun  1 01:48:44 2026 ] Dev WER: 91.30%
# [ Mon Jun  1 01:48:45 2026 ] 	Epoch: 9, Batch(0/56) done. Loss: 125.82  lr:0.000400
# [ Mon Jun  1 01:48:45 2026 ] 	CR_ConvCTC_static: 42.62, CR_SeqCTC_static: 14.18, CR_Conv_static: 2.13, CR_Seq_static: 0.00, CR_ConvCTC_motion: 18.69, CR_SeqCTC_motion: 14.53, CR_Conv_motion: 0.45, CR_Seq_motion: 0.02, CR_ConvCTC_fusion: 20.03, CR_SeqCTC_fusion: 12.53, CR_Conv_fusion: 0.62, CR_Seq_fusion: 0.02
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:49:37 2026 ] 	Mean training loss: 158.4591116224.
# [ Mon Jun  1 01:49:37 2026 ] 	Epoch 9 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.80it/s]
# [ Mon Jun  1 01:49:42 2026 ] [DEV EVAL] Total Inference Time: 4.76s
# [ Mon Jun  1 01:49:42 2026 ] [DEV EVAL] Inference Speed: 3554.06 Frames/s, 31.52 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:49:42 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:49:42 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:49:42 2026 ] [DEV] Conv1D temporal WER:  93.60%, BiLSTM contextual WER:  89.40%
# [ Mon Jun  1 01:49:42 2026 ] Dev WER: 89.40%
# [ Mon Jun  1 01:49:43 2026 ] 	Epoch: 10, Batch(0/56) done. Loss: 166.61  lr:0.000400
# [ Mon Jun  1 01:49:43 2026 ] 	CR_ConvCTC_static: 71.00, CR_SeqCTC_static: 17.24, CR_Conv_static: 0.14, CR_Seq_static: 0.00, CR_ConvCTC_motion: 23.94, CR_SeqCTC_motion: 15.17, CR_Conv_motion: 0.43, CR_Seq_motion: 0.05, CR_ConvCTC_fusion: 23.72, CR_SeqCTC_fusion: 14.52, CR_Conv_fusion: 0.35, CR_Seq_fusion: 0.04
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:50:36 2026 ] 	Mean training loss: 161.3491279057.
# [ Mon Jun  1 01:50:36 2026 ] 	Epoch 10 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.02it/s]
# [ Mon Jun  1 01:50:40 2026 ] [DEV EVAL] Total Inference Time: 4.53s
# [ Mon Jun  1 01:50:40 2026 ] [DEV EVAL] Inference Speed: 3733.48 Frames/s, 33.11 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:50:40 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:50:41 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:50:41 2026 ] [DEV] Conv1D temporal WER:  93.30%, BiLSTM contextual WER:  91.00%
# [ Mon Jun  1 01:50:41 2026 ] Dev WER: 91.00%
# [ Mon Jun  1 01:50:42 2026 ] 	Epoch: 11, Batch(0/56) done. Loss: 164.59  lr:0.000400
# [ Mon Jun  1 01:50:42 2026 ] 	CR_ConvCTC_static: 63.39, CR_SeqCTC_static: 17.31, CR_Conv_static: 4.09, CR_Seq_static: 0.02, CR_ConvCTC_motion: 23.48, CR_SeqCTC_motion: 15.59, CR_Conv_motion: 0.54, CR_Seq_motion: 0.03, CR_ConvCTC_fusion: 24.97, CR_SeqCTC_fusion: 14.65, CR_Conv_fusion: 0.51, CR_Seq_fusion: 0.02
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 01:51:34 2026 ] 	Mean training loss: 157.9745356696.
# [ Mon Jun  1 01:51:34 2026 ] 	Epoch 11 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.04it/s]
# [ Mon Jun  1 01:51:39 2026 ] [DEV EVAL] Total Inference Time: 4.51s
# [ Mon Jun  1 01:51:39 2026 ] [DEV EVAL] Inference Speed: 3754.42 Frames/s, 33.29 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:51:39 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:51:39 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:51:39 2026 ] [DEV] Conv1D temporal WER:  92.20%, BiLSTM contextual WER:  84.50%
# [ Mon Jun  1 01:51:39 2026 ] Dev WER: 84.50%
# [ Mon Jun  1 01:51:41 2026 ] 	Epoch: 12, Batch(0/56) done. Loss: 187.50  lr:0.000400
# [ Mon Jun  1 01:51:41 2026 ] 	CR_ConvCTC_static: 87.64, CR_SeqCTC_static: 18.13, CR_Conv_static: 0.21, CR_Seq_static: 0.00, CR_ConvCTC_motion: 26.51, CR_SeqCTC_motion: 15.07, CR_Conv_motion: 0.49, CR_Seq_motion: 0.03, CR_ConvCTC_fusion: 24.06, CR_SeqCTC_fusion: 14.91, CR_Conv_fusion: 0.41, CR_Seq_fusion: 0.03
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 01:52:33 2026 ] 	Mean training loss: 156.5145814078.
# [ Mon Jun  1 01:52:33 2026 ] 	Epoch 12 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.75it/s]
# [ Mon Jun  1 01:52:38 2026 ] [DEV EVAL] Total Inference Time: 4.85s
# [ Mon Jun  1 01:52:38 2026 ] [DEV EVAL] Inference Speed: 3485.26 Frames/s, 30.91 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:52:38 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:52:38 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:52:38 2026 ] [DEV] Conv1D temporal WER:  93.70%, BiLSTM contextual WER:  79.30%
# [ Mon Jun  1 01:52:38 2026 ] Dev WER: 79.30%
# [ Mon Jun  1 01:52:39 2026 ] 	Epoch: 13, Batch(0/56) done. Loss: 150.73  lr:0.000400
# [ Mon Jun  1 01:52:39 2026 ] 	CR_ConvCTC_static: 61.34, CR_SeqCTC_static: 16.21, CR_Conv_static: 0.24, CR_Seq_static: 0.00, CR_ConvCTC_motion: 21.08, CR_SeqCTC_motion: 14.70, CR_Conv_motion: 0.49, CR_Seq_motion: 0.11, CR_ConvCTC_fusion: 21.31, CR_SeqCTC_fusion: 14.66, CR_Conv_fusion: 0.53, CR_Seq_fusion: 0.05
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:53:32 2026 ] 	Mean training loss: 154.5227697917.
# [ Mon Jun  1 01:53:32 2026 ] 	Epoch 13 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.93it/s]
# [ Mon Jun  1 01:53:36 2026 ] [DEV EVAL] Total Inference Time: 4.60s
# [ Mon Jun  1 01:53:36 2026 ] [DEV EVAL] Inference Speed: 3678.55 Frames/s, 32.62 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:53:36 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:53:36 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:53:37 2026 ] [DEV] Conv1D temporal WER:  93.80%, BiLSTM contextual WER:  84.80%
# [ Mon Jun  1 01:53:37 2026 ] Dev WER: 84.80%
# [ Mon Jun  1 01:53:38 2026 ] 	Epoch: 14, Batch(0/56) done. Loss: 153.24  lr:0.000400
# [ Mon Jun  1 01:53:38 2026 ] 	CR_ConvCTC_static: 68.70, CR_SeqCTC_static: 14.48, CR_Conv_static: 0.54, CR_Seq_static: 0.00, CR_ConvCTC_motion: 22.40, CR_SeqCTC_motion: 11.50, CR_Conv_motion: 0.72, CR_Seq_motion: 0.05, CR_ConvCTC_fusion: 21.64, CR_SeqCTC_fusion: 12.55, CR_Conv_fusion: 0.61, CR_Seq_fusion: 0.04
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 01:54:31 2026 ] 	Mean training loss: 155.7790294375.
# [ Mon Jun  1 01:54:31 2026 ] 	Epoch 14 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.99it/s]
# [ Mon Jun  1 01:54:36 2026 ] [DEV EVAL] Total Inference Time: 4.56s
# [ Mon Jun  1 01:54:36 2026 ] [DEV EVAL] Inference Speed: 3709.71 Frames/s, 32.90 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:54:36 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:54:36 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:54:36 2026 ] [DEV] Conv1D temporal WER:  93.10%, BiLSTM contextual WER:  89.50%
# [ Mon Jun  1 01:54:36 2026 ] Dev WER: 89.50%
# [ Mon Jun  1 01:54:37 2026 ] 	Epoch: 15, Batch(0/56) done. Loss: 155.90  lr:0.000400
# [ Mon Jun  1 01:54:37 2026 ] 	CR_ConvCTC_static: 74.90, CR_SeqCTC_static: 16.62, CR_Conv_static: 0.42, CR_Seq_static: 0.00, CR_ConvCTC_motion: 20.79, CR_SeqCTC_motion: 9.30, CR_Conv_motion: 0.35, CR_Seq_motion: 0.04, CR_ConvCTC_fusion: 20.85, CR_SeqCTC_fusion: 12.09, CR_Conv_fusion: 0.45, CR_Seq_fusion: 0.09
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 01:55:30 2026 ] 	Mean training loss: 153.5617175783.
# [ Mon Jun  1 01:55:30 2026 ] 	Epoch 15 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.77it/s]
# [ Mon Jun  1 01:55:35 2026 ] [DEV EVAL] Total Inference Time: 4.79s
# [ Mon Jun  1 01:55:35 2026 ] [DEV EVAL] Inference Speed: 3531.54 Frames/s, 31.32 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:55:35 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:55:35 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:55:35 2026 ] [DEV] Conv1D temporal WER:  100.00%, BiLSTM contextual WER:  94.70%
# [ Mon Jun  1 01:55:35 2026 ] Dev WER: 94.70%
# [ Mon Jun  1 01:55:37 2026 ] 	Epoch: 16, Batch(0/56) done. Loss: 190.91  lr:0.000400
# [ Mon Jun  1 01:55:37 2026 ] 	CR_ConvCTC_static: 95.08, CR_SeqCTC_static: 18.74, CR_Conv_static: 0.49, CR_Seq_static: 0.00, CR_ConvCTC_motion: 23.19, CR_SeqCTC_motion: 12.69, CR_Conv_motion: 0.57, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 24.22, CR_SeqCTC_fusion: 15.27, CR_Conv_fusion: 0.54, CR_Seq_fusion: 0.05
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 01:56:30 2026 ] 	Mean training loss: 153.9307934897.
# [ Mon Jun  1 01:56:30 2026 ] 	Epoch 16 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.03it/s]
# [ Mon Jun  1 01:56:35 2026 ] [DEV EVAL] Total Inference Time: 4.52s
# [ Mon Jun  1 01:56:35 2026 ] [DEV EVAL] Inference Speed: 3741.84 Frames/s, 33.18 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:56:35 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:56:35 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:56:35 2026 ] [DEV] Conv1D temporal WER:  93.80%, BiLSTM contextual WER:  78.00%
# [ Mon Jun  1 01:56:35 2026 ] Dev WER: 78.00%
# [ Mon Jun  1 01:56:36 2026 ] 	Epoch: 17, Batch(0/56) done. Loss: 129.11  lr:0.000400
# [ Mon Jun  1 01:56:36 2026 ] 	CR_ConvCTC_static: 39.80, CR_SeqCTC_static: 17.00, CR_Conv_static: 0.50, CR_Seq_static: 0.00, CR_ConvCTC_motion: 22.24, CR_SeqCTC_motion: 13.86, CR_Conv_motion: 0.92, CR_Seq_motion: 0.13, CR_ConvCTC_fusion: 20.30, CR_SeqCTC_fusion: 13.91, CR_Conv_fusion: 0.39, CR_Seq_fusion: 0.06
# 100% 56/56 [00:52<00:00,  1.06it/s]
# [ Mon Jun  1 01:57:28 2026 ] 	Mean training loss: 143.1650848389.
# [ Mon Jun  1 01:57:28 2026 ] 	Epoch 17 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.04it/s]
# [ Mon Jun  1 01:57:32 2026 ] [DEV EVAL] Total Inference Time: 4.52s
# [ Mon Jun  1 01:57:32 2026 ] [DEV EVAL] Inference Speed: 3742.79 Frames/s, 33.19 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:57:32 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:57:33 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:57:33 2026 ] [DEV] Conv1D temporal WER:  94.10%, BiLSTM contextual WER:  102.10%
# [ Mon Jun  1 01:57:33 2026 ] Dev WER: 94.10%
# [ Mon Jun  1 01:57:34 2026 ] 	Epoch: 18, Batch(0/56) done. Loss: 144.20  lr:0.000400
# [ Mon Jun  1 01:57:34 2026 ] 	CR_ConvCTC_static: 62.19, CR_SeqCTC_static: 16.46, CR_Conv_static: 0.68, CR_Seq_static: 0.00, CR_ConvCTC_motion: 20.89, CR_SeqCTC_motion: 10.29, CR_Conv_motion: 0.61, CR_Seq_motion: 0.06, CR_ConvCTC_fusion: 21.06, CR_SeqCTC_fusion: 11.41, CR_Conv_fusion: 0.47, CR_Seq_fusion: 0.07
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:58:26 2026 ] 	Mean training loss: 136.5852812358.
# [ Mon Jun  1 01:58:26 2026 ] 	Epoch 18 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.82it/s]
# [ Mon Jun  1 01:58:31 2026 ] [DEV EVAL] Total Inference Time: 4.73s
# [ Mon Jun  1 01:58:31 2026 ] [DEV EVAL] Inference Speed: 3576.50 Frames/s, 31.71 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:58:31 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:58:31 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:58:31 2026 ] [DEV] Conv1D temporal WER:  94.40%, BiLSTM contextual WER:  92.30%
# [ Mon Jun  1 01:58:31 2026 ] Dev WER: 92.30%
# [ Mon Jun  1 01:58:33 2026 ] 	Epoch: 19, Batch(0/56) done. Loss: 148.84  lr:0.000400
# [ Mon Jun  1 01:58:33 2026 ] 	CR_ConvCTC_static: 64.92, CR_SeqCTC_static: 16.35, CR_Conv_static: 0.70, CR_Seq_static: 0.00, CR_ConvCTC_motion: 25.02, CR_SeqCTC_motion: 8.41, CR_Conv_motion: 0.51, CR_Seq_motion: 0.07, CR_ConvCTC_fusion: 22.53, CR_SeqCTC_fusion: 9.80, CR_Conv_fusion: 0.49, CR_Seq_fusion: 0.04
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 01:59:25 2026 ] 	Mean training loss: 131.3535210746.
# [ Mon Jun  1 01:59:25 2026 ] 	Epoch 19 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.85it/s]
# [ Mon Jun  1 01:59:29 2026 ] [DEV EVAL] Total Inference Time: 4.69s
# [ Mon Jun  1 01:59:29 2026 ] [DEV EVAL] Inference Speed: 3608.28 Frames/s, 32.00 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:59:29 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 01:59:30 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 01:59:30 2026 ] [DEV] Conv1D temporal WER:  99.30%, BiLSTM contextual WER:  92.70%
# [ Mon Jun  1 01:59:30 2026 ] Dev WER: 92.70%
# [ Mon Jun  1 01:59:31 2026 ] 	Epoch: 20, Batch(0/56) done. Loss: 120.72  lr:0.000040
# [ Mon Jun  1 01:59:31 2026 ] 	CR_ConvCTC_static: 45.85, CR_SeqCTC_static: 15.09, CR_Conv_static: 0.83, CR_Seq_static: 0.00, CR_ConvCTC_motion: 18.74, CR_SeqCTC_motion: 6.70, CR_Conv_motion: 0.48, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 22.04, CR_SeqCTC_fusion: 10.15, CR_Conv_fusion: 0.66, CR_Seq_fusion: 0.09
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 02:00:24 2026 ] 	Mean training loss: 127.8449791500.
# [ Mon Jun  1 02:00:24 2026 ] 	Epoch 20 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.02it/s]
# [ Mon Jun  1 02:00:29 2026 ] [DEV EVAL] Total Inference Time: 4.53s
# [ Mon Jun  1 02:00:29 2026 ] [DEV EVAL] Inference Speed: 3731.26 Frames/s, 33.09 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:00:29 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:00:29 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:00:29 2026 ] [DEV] Conv1D temporal WER:  92.00%, BiLSTM contextual WER:  75.20%
# [ Mon Jun  1 02:00:29 2026 ] Dev WER: 75.20%
# [ Mon Jun  1 02:00:43 2026 ] 	Epoch: 21, Batch(0/56) done. Loss: 103.60  lr:0.000040
# [ Mon Jun  1 02:00:43 2026 ] 	CR_ConvCTC_static: 33.32, CR_SeqCTC_static: 14.62, CR_Conv_static: 0.65, CR_Seq_static: 0.00, CR_ConvCTC_motion: 16.42, CR_SeqCTC_motion: 8.68, CR_Conv_motion: 0.84, CR_Seq_motion: 0.35, CR_ConvCTC_fusion: 18.26, CR_SeqCTC_fusion: 9.29, CR_Conv_fusion: 1.04, CR_Seq_fusion: 0.12
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:01:36 2026 ] 	Mean training loss: 128.5657198770.
# [ Mon Jun  1 02:01:36 2026 ] 	Epoch 21 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.76it/s]
# [ Mon Jun  1 02:01:41 2026 ] [DEV EVAL] Total Inference Time: 4.83s
# [ Mon Jun  1 02:01:41 2026 ] [DEV EVAL] Inference Speed: 3504.97 Frames/s, 31.08 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:01:41 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:01:41 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:01:41 2026 ] [DEV] Conv1D temporal WER:  92.20%, BiLSTM contextual WER:  63.60%
# [ Mon Jun  1 02:01:41 2026 ] Dev WER: 63.60%
# [ Mon Jun  1 02:01:51 2026 ] 	Epoch: 22, Batch(0/56) done. Loss: 109.05  lr:0.000040
# [ Mon Jun  1 02:01:51 2026 ] 	CR_ConvCTC_static: 43.59, CR_SeqCTC_static: 13.38, CR_Conv_static: 0.57, CR_Seq_static: 0.01, CR_ConvCTC_motion: 18.44, CR_SeqCTC_motion: 4.78, CR_Conv_motion: 0.77, CR_Seq_motion: 0.07, CR_ConvCTC_fusion: 18.65, CR_SeqCTC_fusion: 7.90, CR_Conv_fusion: 0.75, CR_Seq_fusion: 0.14
# 100% 56/56 [00:53<00:00,  1.06it/s]
# [ Mon Jun  1 02:02:43 2026 ] 	Mean training loss: 123.9549469267.
# [ Mon Jun  1 02:02:43 2026 ] 	Epoch 22 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.82it/s]
# [ Mon Jun  1 02:02:48 2026 ] [DEV EVAL] Total Inference Time: 4.74s
# [ Mon Jun  1 02:02:48 2026 ] [DEV EVAL] Inference Speed: 3567.67 Frames/s, 31.64 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:02:48 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:02:48 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:02:49 2026 ] [DEV] Conv1D temporal WER:  91.90%, BiLSTM contextual WER:  64.30%
# [ Mon Jun  1 02:02:49 2026 ] Dev WER: 64.30%
# [ Mon Jun  1 02:02:53 2026 ] 	Epoch: 23, Batch(0/56) done. Loss: 137.69  lr:0.000040
# [ Mon Jun  1 02:02:53 2026 ] 	CR_ConvCTC_static: 54.57, CR_SeqCTC_static: 17.61, CR_Conv_static: 0.69, CR_Seq_static: 0.00, CR_ConvCTC_motion: 22.84, CR_SeqCTC_motion: 7.41, CR_Conv_motion: 0.59, CR_Seq_motion: 0.07, CR_ConvCTC_fusion: 23.34, CR_SeqCTC_fusion: 10.07, CR_Conv_fusion: 0.45, CR_Seq_fusion: 0.05
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 02:03:46 2026 ] 	Mean training loss: 122.4520834514.
# [ Mon Jun  1 02:03:46 2026 ] 	Epoch 23 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.00it/s]
# [ Mon Jun  1 02:03:50 2026 ] [DEV EVAL] Total Inference Time: 4.54s
# [ Mon Jun  1 02:03:50 2026 ] [DEV EVAL] Inference Speed: 3723.19 Frames/s, 33.01 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:03:50 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:03:51 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:03:51 2026 ] [DEV] Conv1D temporal WER:  91.20%, BiLSTM contextual WER:  62.90%
# [ Mon Jun  1 02:03:51 2026 ] Dev WER: 62.90%
# [ Mon Jun  1 02:04:04 2026 ] 	Epoch: 24, Batch(0/56) done. Loss: 106.58  lr:0.000040
# [ Mon Jun  1 02:04:04 2026 ] 	CR_ConvCTC_static: 38.17, CR_SeqCTC_static: 15.47, CR_Conv_static: 0.59, CR_Seq_static: 0.00, CR_ConvCTC_motion: 18.58, CR_SeqCTC_motion: 6.54, CR_Conv_motion: 0.50, CR_Seq_motion: 0.11, CR_ConvCTC_fusion: 18.63, CR_SeqCTC_fusion: 7.72, CR_Conv_fusion: 0.21, CR_Seq_fusion: 0.07
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:04:57 2026 ] 	Mean training loss: 121.5918049131.
# [ Mon Jun  1 02:04:57 2026 ] 	Epoch 24 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.01it/s]
# [ Mon Jun  1 02:05:02 2026 ] [DEV EVAL] Total Inference Time: 4.54s
# [ Mon Jun  1 02:05:02 2026 ] [DEV EVAL] Inference Speed: 3728.59 Frames/s, 33.06 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:05:02 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:05:02 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:05:02 2026 ] [DEV] Conv1D temporal WER:  92.00%, BiLSTM contextual WER:  60.70%
# [ Mon Jun  1 02:05:02 2026 ] Dev WER: 60.70%
# [ Mon Jun  1 02:05:21 2026 ] 	Epoch: 25, Batch(0/56) done. Loss: 147.95  lr:0.000040
# [ Mon Jun  1 02:05:21 2026 ] 	CR_ConvCTC_static: 62.55, CR_SeqCTC_static: 17.87, CR_Conv_static: 0.56, CR_Seq_static: 0.00, CR_ConvCTC_motion: 22.99, CR_SeqCTC_motion: 7.26, CR_Conv_motion: 0.68, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 24.41, CR_SeqCTC_fusion: 10.75, CR_Conv_fusion: 0.72, CR_Seq_fusion: 0.09
# 100% 56/56 [00:52<00:00,  1.06it/s]
# [ Mon Jun  1 02:06:12 2026 ] 	Mean training loss: 121.2100229263.
# [ Mon Jun  1 02:06:12 2026 ] 	Epoch 25 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.97it/s]
# [ Mon Jun  1 02:06:17 2026 ] [DEV EVAL] Total Inference Time: 4.56s
# [ Mon Jun  1 02:06:17 2026 ] [DEV EVAL] Inference Speed: 3705.71 Frames/s, 32.86 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:06:17 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:06:17 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:06:17 2026 ] [DEV] Conv1D temporal WER:  90.20%, BiLSTM contextual WER:  58.70%
# [ Mon Jun  1 02:06:17 2026 ] Dev WER: 58.70%
# [ Mon Jun  1 02:06:24 2026 ] 	Epoch: 26, Batch(0/56) done. Loss: 113.09  lr:0.000040
# [ Mon Jun  1 02:06:24 2026 ] 	CR_ConvCTC_static: 35.80, CR_SeqCTC_static: 15.86, CR_Conv_static: 0.39, CR_Seq_static: 0.00, CR_ConvCTC_motion: 21.44, CR_SeqCTC_motion: 6.91, CR_Conv_motion: 0.71, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 20.95, CR_SeqCTC_fusion: 10.24, CR_Conv_fusion: 0.63, CR_Seq_fusion: 0.08
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 02:07:18 2026 ] 	Mean training loss: 122.3152830941.
# [ Mon Jun  1 02:07:18 2026 ] 	Epoch 26 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.79it/s]
# [ Mon Jun  1 02:07:23 2026 ] [DEV EVAL] Total Inference Time: 4.78s
# [ Mon Jun  1 02:07:23 2026 ] [DEV EVAL] Inference Speed: 3538.57 Frames/s, 31.38 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:07:23 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:07:23 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:07:23 2026 ] [DEV] Conv1D temporal WER:  90.50%, BiLSTM contextual WER:  62.90%
# [ Mon Jun  1 02:07:23 2026 ] Dev WER: 62.90%
# [ Mon Jun  1 02:07:38 2026 ] 	Epoch: 27, Batch(0/56) done. Loss: 124.83  lr:0.000040
# [ Mon Jun  1 02:07:38 2026 ] 	CR_ConvCTC_static: 45.74, CR_SeqCTC_static: 16.31, CR_Conv_static: 0.35, CR_Seq_static: 0.00, CR_ConvCTC_motion: 23.07, CR_SeqCTC_motion: 6.88, CR_Conv_motion: 0.68, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 23.09, CR_SeqCTC_fusion: 8.13, CR_Conv_fusion: 0.42, CR_Seq_fusion: 0.06
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 02:08:31 2026 ] 	Mean training loss: 123.2131359918.
# [ Mon Jun  1 02:08:31 2026 ] 	Epoch 27 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.03it/s]
# [ Mon Jun  1 02:08:36 2026 ] [DEV EVAL] Total Inference Time: 4.53s
# [ Mon Jun  1 02:08:36 2026 ] [DEV EVAL] Inference Speed: 3737.66 Frames/s, 33.14 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:08:36 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:08:36 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:08:36 2026 ] [DEV] Conv1D temporal WER:  91.70%, BiLSTM contextual WER:  65.90%
# [ Mon Jun  1 02:08:36 2026 ] Dev WER: 65.90%
# [ Mon Jun  1 02:08:44 2026 ] 	Epoch: 28, Batch(0/56) done. Loss: 106.23  lr:0.000040
# [ Mon Jun  1 02:08:44 2026 ] 	CR_ConvCTC_static: 35.70, CR_SeqCTC_static: 15.35, CR_Conv_static: 0.74, CR_Seq_static: 0.01, CR_ConvCTC_motion: 19.31, CR_SeqCTC_motion: 6.05, CR_Conv_motion: 0.99, CR_Seq_motion: 0.12, CR_ConvCTC_fusion: 19.59, CR_SeqCTC_fusion: 7.68, CR_Conv_fusion: 0.63, CR_Seq_fusion: 0.08
# 100% 56/56 [00:54<00:00,  1.03it/s]
# [ Mon Jun  1 02:09:37 2026 ] 	Mean training loss: 118.8292759487.
# [ Mon Jun  1 02:09:37 2026 ] 	Epoch 28 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.00it/s]
# [ Mon Jun  1 02:09:42 2026 ] [DEV EVAL] Total Inference Time: 4.55s
# [ Mon Jun  1 02:09:42 2026 ] [DEV EVAL] Inference Speed: 3715.66 Frames/s, 32.95 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:09:42 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:09:42 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:09:42 2026 ] [DEV] Conv1D temporal WER:  215.00%, BiLSTM contextual WER:  95.20%
# [ Mon Jun  1 02:09:42 2026 ] Dev WER: 95.20%
# [ Mon Jun  1 02:09:46 2026 ] 	Epoch: 29, Batch(0/56) done. Loss: 115.74  lr:0.000040
# [ Mon Jun  1 02:09:46 2026 ] 	CR_ConvCTC_static: 37.71, CR_SeqCTC_static: 17.26, CR_Conv_static: 0.44, CR_Seq_static: 0.00, CR_ConvCTC_motion: 19.48, CR_SeqCTC_motion: 7.91, CR_Conv_motion: 0.62, CR_Seq_motion: 0.21, CR_ConvCTC_fusion: 20.71, CR_SeqCTC_fusion: 10.67, CR_Conv_fusion: 0.55, CR_Seq_fusion: 0.17
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 02:10:39 2026 ] 	Mean training loss: 123.0671445302.
# [ Mon Jun  1 02:10:39 2026 ] 	Epoch 29 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.77it/s]
# [ Mon Jun  1 02:10:44 2026 ] [DEV EVAL] Total Inference Time: 4.81s
# [ Mon Jun  1 02:10:44 2026 ] [DEV EVAL] Inference Speed: 3515.99 Frames/s, 31.18 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:10:44 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:10:44 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:10:44 2026 ] [DEV] Conv1D temporal WER:  94.10%, BiLSTM contextual WER:  84.80%
# [ Mon Jun  1 02:10:44 2026 ] Dev WER: 84.80%
# [ Mon Jun  1 02:10:48 2026 ] 	Epoch: 30, Batch(0/56) done. Loss: 106.31  lr:0.000040
# [ Mon Jun  1 02:10:48 2026 ] 	CR_ConvCTC_static: 36.90, CR_SeqCTC_static: 14.19, CR_Conv_static: 0.75, CR_Seq_static: 0.00, CR_ConvCTC_motion: 17.17, CR_SeqCTC_motion: 6.48, CR_Conv_motion: 0.64, CR_Seq_motion: 0.14, CR_ConvCTC_fusion: 19.50, CR_SeqCTC_fusion: 9.63, CR_Conv_fusion: 0.79, CR_Seq_fusion: 0.10
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 02:11:40 2026 ] 	Mean training loss: 118.0723154885.
# [ Mon Jun  1 02:11:40 2026 ] 	Epoch 30 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.01it/s]
# [ Mon Jun  1 02:11:45 2026 ] [DEV EVAL] Total Inference Time: 4.54s
# [ Mon Jun  1 02:11:45 2026 ] [DEV EVAL] Inference Speed: 3727.17 Frames/s, 33.05 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:11:45 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:11:45 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:11:45 2026 ] [DEV] Conv1D temporal WER:  93.60%, BiLSTM contextual WER:  68.70%
# [ Mon Jun  1 02:11:45 2026 ] Dev WER: 68.70%
# [ Mon Jun  1 02:12:39 2026 ] 	Epoch: 31, Batch(0/56) done. Loss: 127.31  lr:0.000040
# [ Mon Jun  1 02:12:39 2026 ] 	CR_ConvCTC_static: 46.68, CR_SeqCTC_static: 15.44, CR_Conv_static: 0.30, CR_Seq_static: 0.00, CR_ConvCTC_motion: 23.50, CR_SeqCTC_motion: 8.22, CR_Conv_motion: 1.09, CR_Seq_motion: 0.15, CR_ConvCTC_fusion: 22.23, CR_SeqCTC_fusion: 8.83, CR_Conv_fusion: 0.81, CR_Seq_fusion: 0.07
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:13:31 2026 ] 	Mean training loss: 117.5281521933.
# [ Mon Jun  1 02:13:31 2026 ] 	Epoch 31 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.71it/s]
# [ Mon Jun  1 02:13:36 2026 ] [DEV EVAL] Total Inference Time: 4.90s
# [ Mon Jun  1 02:13:36 2026 ] [DEV EVAL] Inference Speed: 3450.56 Frames/s, 30.60 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:13:36 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:13:36 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:13:36 2026 ] [DEV] Conv1D temporal WER:  232.40%, BiLSTM contextual WER:  96.50%
# [ Mon Jun  1 02:13:36 2026 ] Dev WER: 96.50%
# [ Mon Jun  1 02:13:40 2026 ] 	Epoch: 32, Batch(0/56) done. Loss: 116.65  lr:0.000040
# [ Mon Jun  1 02:13:40 2026 ] 	CR_ConvCTC_static: 40.58, CR_SeqCTC_static: 17.56, CR_Conv_static: 0.80, CR_Seq_static: 0.00, CR_ConvCTC_motion: 19.62, CR_SeqCTC_motion: 6.61, CR_Conv_motion: 0.83, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 19.52, CR_SeqCTC_fusion: 10.59, CR_Conv_fusion: 0.27, CR_Seq_fusion: 0.18
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 02:14:33 2026 ] 	Mean training loss: 118.2313507625.
# [ Mon Jun  1 02:14:33 2026 ] 	Epoch 32 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.99it/s]
# [ Mon Jun  1 02:14:38 2026 ] [DEV EVAL] Total Inference Time: 4.57s
# [ Mon Jun  1 02:14:38 2026 ] [DEV EVAL] Inference Speed: 3702.54 Frames/s, 32.83 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:14:38 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:14:38 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:14:38 2026 ] [DEV] Conv1D temporal WER:  91.60%, BiLSTM contextual WER:  55.50%
# [ Mon Jun  1 02:14:38 2026 ] Dev WER: 55.50%
# [ Mon Jun  1 02:15:31 2026 ] 	Epoch: 33, Batch(0/56) done. Loss: 103.14  lr:0.000040
# [ Mon Jun  1 02:15:31 2026 ] 	CR_ConvCTC_static: 34.79, CR_SeqCTC_static: 15.07, CR_Conv_static: 0.66, CR_Seq_static: 0.00, CR_ConvCTC_motion: 17.76, CR_SeqCTC_motion: 5.46, CR_Conv_motion: 0.59, CR_Seq_motion: 0.14, CR_ConvCTC_fusion: 19.33, CR_SeqCTC_fusion: 8.65, CR_Conv_fusion: 0.57, CR_Seq_fusion: 0.11
# 100% 56/56 [00:52<00:00,  1.06it/s]
# [ Mon Jun  1 02:16:22 2026 ] 	Mean training loss: 116.3749261584.
# [ Mon Jun  1 02:16:22 2026 ] 	Epoch 33 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.81it/s]
# [ Mon Jun  1 02:16:27 2026 ] [DEV EVAL] Total Inference Time: 4.77s
# [ Mon Jun  1 02:16:27 2026 ] [DEV EVAL] Inference Speed: 3548.02 Frames/s, 31.46 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:16:27 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:16:27 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:16:28 2026 ] [DEV] Conv1D temporal WER:  92.20%, BiLSTM contextual WER:  56.80%
# [ Mon Jun  1 02:16:28 2026 ] Dev WER: 56.80%
# [ Mon Jun  1 02:16:32 2026 ] 	Epoch: 34, Batch(0/56) done. Loss: 127.39  lr:0.000040
# [ Mon Jun  1 02:16:32 2026 ] 	CR_ConvCTC_static: 41.88, CR_SeqCTC_static: 17.84, CR_Conv_static: 0.94, CR_Seq_static: 0.00, CR_ConvCTC_motion: 24.95, CR_SeqCTC_motion: 7.19, CR_Conv_motion: 1.46, CR_Seq_motion: 0.15, CR_ConvCTC_fusion: 21.86, CR_SeqCTC_fusion: 10.24, CR_Conv_fusion: 0.77, CR_Seq_fusion: 0.10
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 02:17:24 2026 ] 	Mean training loss: 115.5828018188.
# [ Mon Jun  1 02:17:24 2026 ] 	Epoch 34 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.01it/s]
# [ Mon Jun  1 02:17:29 2026 ] [DEV EVAL] Total Inference Time: 4.54s
# [ Mon Jun  1 02:17:29 2026 ] [DEV EVAL] Inference Speed: 3728.33 Frames/s, 33.06 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:17:29 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:17:29 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:17:29 2026 ] [DEV] Conv1D temporal WER:  92.40%, BiLSTM contextual WER:  54.50%
# [ Mon Jun  1 02:17:29 2026 ] Dev WER: 54.50%
# [ Mon Jun  1 02:17:48 2026 ] 	Epoch: 35, Batch(0/56) done. Loss: 80.68  lr:0.000004
# [ Mon Jun  1 02:17:48 2026 ] 	CR_ConvCTC_static: 29.67, CR_SeqCTC_static: 11.86, CR_Conv_static: 0.58, CR_Seq_static: 0.00, CR_ConvCTC_motion: 13.16, CR_SeqCTC_motion: 3.10, CR_Conv_motion: 0.46, CR_Seq_motion: 0.08, CR_ConvCTC_fusion: 15.48, CR_SeqCTC_fusion: 5.44, CR_Conv_fusion: 0.64, CR_Seq_fusion: 0.21
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:18:42 2026 ] 	Mean training loss: 117.5946978160.
# [ Mon Jun  1 02:18:42 2026 ] 	Epoch 35 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.95it/s]
# [ Mon Jun  1 02:18:46 2026 ] [DEV EVAL] Total Inference Time: 4.58s
# [ Mon Jun  1 02:18:46 2026 ] [DEV EVAL] Inference Speed: 3697.43 Frames/s, 32.79 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:18:46 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:18:46 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:18:47 2026 ] [DEV] Conv1D temporal WER:  92.30%, BiLSTM contextual WER:  54.30%
# [ Mon Jun  1 02:18:47 2026 ] Dev WER: 54.30%
# [ Mon Jun  1 02:19:07 2026 ] 	Epoch: 36, Batch(0/56) done. Loss: 141.21  lr:0.000004
# [ Mon Jun  1 02:19:07 2026 ] 	CR_ConvCTC_static: 59.10, CR_SeqCTC_static: 17.88, CR_Conv_static: 1.04, CR_Seq_static: 0.00, CR_ConvCTC_motion: 23.06, CR_SeqCTC_motion: 6.94, CR_Conv_motion: 0.82, CR_Seq_motion: 0.09, CR_ConvCTC_fusion: 22.57, CR_SeqCTC_fusion: 9.27, CR_Conv_fusion: 0.35, CR_Seq_fusion: 0.07
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:20:00 2026 ] 	Mean training loss: 114.6252343314.
# [ Mon Jun  1 02:20:00 2026 ] 	Epoch 36 processed 448 samples in 56 batches.
# 100% 19/19 [00:05<00:00,  3.73it/s]
# [ Mon Jun  1 02:20:05 2026 ] [DEV EVAL] Total Inference Time: 4.84s
# [ Mon Jun  1 02:20:05 2026 ] [DEV EVAL] Inference Speed: 3495.77 Frames/s, 31.00 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:20:05 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:20:05 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:20:05 2026 ] [DEV] Conv1D temporal WER:  92.40%, BiLSTM contextual WER:  53.30%
# [ Mon Jun  1 02:20:05 2026 ] Dev WER: 53.30%
# [ Mon Jun  1 02:20:21 2026 ] 	Epoch: 37, Batch(0/56) done. Loss: 140.25  lr:0.000004
# [ Mon Jun  1 02:20:21 2026 ] 	CR_ConvCTC_static: 55.45, CR_SeqCTC_static: 15.72, CR_Conv_static: 1.14, CR_Seq_static: 0.00, CR_ConvCTC_motion: 22.49, CR_SeqCTC_motion: 10.03, CR_Conv_motion: 0.77, CR_Seq_motion: 0.17, CR_ConvCTC_fusion: 22.60, CR_SeqCTC_fusion: 11.13, CR_Conv_fusion: 0.67, CR_Seq_fusion: 0.07
# 100% 56/56 [00:53<00:00,  1.05it/s]
# [ Mon Jun  1 02:21:13 2026 ] 	Mean training loss: 115.3904266357.
# [ Mon Jun  1 02:21:13 2026 ] 	Epoch 37 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  4.00it/s]
# [ Mon Jun  1 02:21:18 2026 ] [DEV EVAL] Total Inference Time: 4.56s
# [ Mon Jun  1 02:21:18 2026 ] [DEV EVAL] Inference Speed: 3711.77 Frames/s, 32.91 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:21:18 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:21:18 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:21:18 2026 ] [DEV] Conv1D temporal WER:  91.70%, BiLSTM contextual WER:  52.40%
# [ Mon Jun  1 02:21:18 2026 ] Dev WER: 52.40%
# [ Mon Jun  1 02:21:31 2026 ] 	Epoch: 38, Batch(0/56) done. Loss: 99.10  lr:0.000004
# [ Mon Jun  1 02:21:31 2026 ] 	CR_ConvCTC_static: 34.34, CR_SeqCTC_static: 13.17, CR_Conv_static: 0.40, CR_Seq_static: 0.00, CR_ConvCTC_motion: 17.29, CR_SeqCTC_motion: 5.95, CR_Conv_motion: 0.79, CR_Seq_motion: 0.15, CR_ConvCTC_fusion: 17.97, CR_SeqCTC_fusion: 8.42, CR_Conv_fusion: 0.50, CR_Seq_fusion: 0.13
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:22:24 2026 ] 	Mean training loss: 114.6493932179.
# [ Mon Jun  1 02:22:24 2026 ] 	Epoch 38 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.87it/s]
# [ Mon Jun  1 02:22:29 2026 ] [DEV EVAL] Total Inference Time: 4.69s
# [ Mon Jun  1 02:22:29 2026 ] [DEV EVAL] Inference Speed: 3603.09 Frames/s, 31.95 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:22:29 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:22:29 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:22:29 2026 ] [DEV] Conv1D temporal WER:  92.60%, BiLSTM contextual WER:  52.90%
# [ Mon Jun  1 02:22:29 2026 ] Dev WER: 52.90%
# [ Mon Jun  1 02:22:33 2026 ] 	Epoch: 39, Batch(0/56) done. Loss: 112.91  lr:0.000004
# [ Mon Jun  1 02:22:33 2026 ] 	CR_ConvCTC_static: 36.45, CR_SeqCTC_static: 18.08, CR_Conv_static: 0.61, CR_Seq_static: 0.01, CR_ConvCTC_motion: 19.18, CR_SeqCTC_motion: 6.90, CR_Conv_motion: 0.97, CR_Seq_motion: 0.21, CR_ConvCTC_fusion: 20.92, CR_SeqCTC_fusion: 8.71, CR_Conv_fusion: 0.69, CR_Seq_fusion: 0.18
# 100% 56/56 [00:53<00:00,  1.04it/s]
# [ Mon Jun  1 02:23:26 2026 ] 	Mean training loss: 114.6378087997.
# [ Mon Jun  1 02:23:26 2026 ] 	Epoch 39 processed 448 samples in 56 batches.
# 100% 19/19 [00:04<00:00,  3.98it/s]
# [ Mon Jun  1 02:23:31 2026 ] [DEV EVAL] Total Inference Time: 4.58s
# [ Mon Jun  1 02:23:31 2026 ] [DEV EVAL] Inference Speed: 3695.06 Frames/s, 32.77 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:23:31 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+SN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+SN/train/dev/tmp.ctm ./work_dir/Baseline+SN/train/dev/tmp2.ctm
# Mon Jun 1 02:23:31 AM UTC 2026
# Preprocess Finished.
# [ Mon Jun  1 02:23:31 2026 ] [DEV] Conv1D temporal WER:  91.60%, BiLSTM contextual WER:  53.60%
# [ Mon Jun  1 02:23:31 2026 ] Dev WER: 53.60%
# [ Mon Jun  1 02:23:47 2026 ] Work dir synced to Google Drive: /content/drive/MyDrive/MSLR_RESULTS/Baseline+SN

# %% [markdown]
# ## 5. Testing Process
# Replace the `--load-weights` path with the correct model weight file (`.pth` or `.pt`) you want to evaluate.

# %%
# !python main.py \\\n    --config ./configs/experiment_configs/main_scenario/M1.yaml \\\n    --phase test \\\n    --load-weights ./work_dir/M1/[REPLACE_WITH_BEST_MODEL_NAME].pt
# Out:
# Loading model
# Loading model finished.
# Loading data
# train 450
# Apply training transform: []
# [SkeletonFeeder] Normalization pipeline: ['missing_kp', 'temporal']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# dev 150
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['missing_kp', 'temporal']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# test_sd 150
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['missing_kp', 'temporal']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# test_si_major 30
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['missing_kp', 'temporal']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# test_si_minor 30
# Apply test transform.
# [SkeletonFeeder] Normalization pipeline: ['missing_kp', 'temporal']
# [SkeletonFeeder] Downsampling enabled, ratio: 0.5
# Loading data finished.
# [ Mon May 25 00:50:47 2026 ] Model:   TwoStream_Cosign.
# [ Mon May 25 00:50:47 2026 ] Weights: ./work_dir/Baseline+MKR+TN/best_dev_00.80_epoch37_model.pt.
# [ Mon May 25 00:50:47 2026 ] --- Testing on Dev ---
# 100% 38/38 [00:07<00:00,  5.02it/s]
# [ Mon May 25 00:50:55 2026 ] [DEV EVAL] Total Inference Time: 4.83s
# [ Mon May 25 00:50:55 2026 ] [DEV EVAL] Inference Speed: 3479.77 Frames/s, 31.07 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/train/dev/output-hypothesis-fusion-dev.ctm ./work_dir/Baseline+MKR+TN/train/dev/tmp.ctm ./work_dir/Baseline+MKR+TN/train/dev/tmp2.ctm
# Mon May 25 12:50:55 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/train/dev/output-hypothesis-conv-fusion-dev.ctm ./work_dir/Baseline+MKR+TN/train/dev/tmp.ctm ./work_dir/Baseline+MKR+TN/train/dev/tmp2.ctm
# Mon May 25 12:50:55 AM UTC 2026
# Preprocess Finished.
# [ Mon May 25 00:50:55 2026 ] [DEV] Conv1D WER:  43.80%, BiLSTM WER:  0.80%
# [ Mon May 25 00:50:55 2026 ] --- Testing on Test SD ---
# 100% 38/38 [00:09<00:00,  4.18it/s]
# [ Mon May 25 00:51:04 2026 ] [TEST_SD EVAL] Total Inference Time: 4.61s
# [ Mon May 25 00:51:04 2026 ] [TEST_SD EVAL] Inference Speed: 3640.62 Frames/s, 32.51 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/test/test_sd/output-hypothesis-fusion-test_sd.ctm ./work_dir/Baseline+MKR+TN/test/test_sd/tmp.ctm ./work_dir/Baseline+MKR+TN/test/test_sd/tmp2.ctm
# Mon May 25 12:51:04 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/test/test_sd/output-hypothesis-conv-fusion-test_sd.ctm ./work_dir/Baseline+MKR+TN/test/test_sd/tmp.ctm ./work_dir/Baseline+MKR+TN/test/test_sd/tmp2.ctm
# Mon May 25 12:51:04 AM UTC 2026
# Preprocess Finished.
# [ Mon May 25 00:51:04 2026 ] [TEST_SD] Conv1D WER:  48.70%, BiLSTM WER:  1.10%
# [ Mon May 25 00:51:04 2026 ] --- Testing on Test SI-Major ---
# 100% 8/8 [00:01<00:00,  5.24it/s]
# [ Mon May 25 00:51:06 2026 ] [TEST_SI_MAJOR EVAL] Total Inference Time: 0.71s
# [ Mon May 25 00:51:06 2026 ] [TEST_SI_MAJOR EVAL] Inference Speed: 4735.11 Frames/s, 42.28 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/test/test_si_major/output-hypothesis-fusion-test_si_major.ctm ./work_dir/Baseline+MKR+TN/test/test_si_major/tmp.ctm ./work_dir/Baseline+MKR+TN/test/test_si_major/tmp2.ctm
# Mon May 25 12:51:06 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/test/test_si_major/output-hypothesis-conv-fusion-test_si_major.ctm ./work_dir/Baseline+MKR+TN/test/test_si_major/tmp.ctm ./work_dir/Baseline+MKR+TN/test/test_si_major/tmp2.ctm
# Mon May 25 12:51:06 AM UTC 2026
# Preprocess Finished.
# [ Mon May 25 00:51:06 2026 ] [TEST_SI_MAJOR] Conv1D WER:  49.00%, BiLSTM WER:  3.50%
# [ Mon May 25 00:51:06 2026 ] --- Testing on Test SI-Minor ---
# 100% 8/8 [00:01<00:00,  5.15it/s]
# [ Mon May 25 00:51:08 2026 ] [TEST_SI_MINOR EVAL] Total Inference Time: 0.79s
# [ Mon May 25 00:51:08 2026 ] [TEST_SI_MINOR EVAL] Inference Speed: 4262.50 Frames/s, 38.06 Sequences/s
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/test/test_si_minor/output-hypothesis-fusion-test_si_minor.ctm ./work_dir/Baseline+MKR+TN/test/test_si_minor/tmp.ctm ./work_dir/Baseline+MKR+TN/test/test_si_minor/tmp2.ctm
# Mon May 25 12:51:08 AM UTC 2026
# Preprocess Finished.
# /content/MSLR_ICCV2025
# preprocess_bisindo.sh ./work_dir/Baseline+MKR+TN/test/test_si_minor/output-hypothesis-conv-fusion-test_si_minor.ctm ./work_dir/Baseline+MKR+TN/test/test_si_minor/tmp.ctm ./work_dir/Baseline+MKR+TN/test/test_si_minor/tmp2.ctm
# Mon May 25 12:51:08 AM UTC 2026
# Preprocess Finished.
# [ Mon May 25 00:51:08 2026 ] [TEST_SI_MINOR] Conv1D WER:  37.80%, BiLSTM WER:  0.70%
# [ Mon May 25 00:51:08 2026 ] Evaluation Done.
#
# [ Mon May 25 00:51:58 2026 ] Work dir synced to Google Drive: /content/drive/MyDrive/MSLR_RESULTS/Baseline+MKR+TN

# %% [markdown]
# ## 6. Download Experiment Results
# Run the cell below to archive the `work_dir` folder. The outputs are separated into two distinct `.zip` files: one containing only the model weights (`experiment_models.zip`) and another containing the experiment logs and results (`experiment_results.zip`).

# %%
import os
from google.colab import files

print("Zipping experiment results (excluding model weights)...")
# !zip -r experiment_results.zip ./work_dir/ -x "*.pt" "*.pth"

print("Downloading files to your local machine...")
if os.path.exists('experiment_results.zip'):
    files.download('experiment_results.zip')
# Out:
#   adding: work_dir/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/cur_dev_01.10_epoch39_model.pt (deflated 7%)
#   adding: work_dir/Baseline+MKR+TN/best_dev_00.80_epoch37_model.pt (deflated 7%)
#   adding: work_dir/Baseline+MKR+TN/train/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-conv-fusion-dev.ctm.sgml (deflated 88%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-conv-fusion-dev.ctm (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-conv-fusion-dev.ctm.pra (deflated 83%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-fusion-dev.ctm.sys (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/output-hypothesis-fusion-dev.ctm (deflated 88%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-fusion-dev.ctm.raw (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-fusion-dev.ctm (deflated 86%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-conv-fusion-dev.ctm.sys (deflated 75%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/tmp.stm (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/tmp2.ctm (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-conv-fusion-dev.ctm.raw (deflated 76%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-fusion-dev.ctm.pra (deflated 92%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/output-hypothesis-conv-fusion-dev.ctm (deflated 86%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/out.output-hypothesis-fusion-dev.ctm.sgml (deflated 92%)
#   adding: work_dir/Baseline+MKR+TN/train/dev/dev_wer.txt (deflated 84%)
#   adding: work_dir/Baseline+MKR+TN/log.txt (deflated 83%)
#   adding: work_dir/Baseline+MKR+TN/test/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-conv-fusion-test_si_major.ctm.sys (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-fusion-test_si_major.ctm.raw (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/output-hypothesis-fusion-test_si_major.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-fusion-test_si_major.ctm.pra (deflated 78%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-conv-fusion-test_si_major.ctm.pra (deflated 74%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/tmp.stm (deflated 69%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/test_si_major_wer.txt (deflated 4%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/tmp2.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-conv-fusion-test_si_major.ctm.raw (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-conv-fusion-test_si_major.ctm.sgml (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/test_si_major.csv (deflated 56%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-fusion-test_si_major.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-fusion-test_si_major.ctm.sys (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-conv-fusion-test_si_major.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/out.output-hypothesis-fusion-test_si_major.ctm.sgml (deflated 81%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_major/output-hypothesis-conv-fusion-test_si_major.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/test_si_minor.csv (deflated 56%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-fusion-test_si_minor.ctm (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/output-hypothesis-conv-fusion-test_si_minor.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-conv-fusion-test_si_minor.ctm.sys (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-conv-fusion-test_si_minor.ctm.sgml (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/tmp.stm (deflated 69%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/tmp2.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-fusion-test_si_minor.ctm.raw (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-fusion-test_si_minor.ctm.sgml (deflated 81%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/test_si_minor_wer.txt (deflated 4%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-conv-fusion-test_si_minor.ctm.pra (deflated 74%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-fusion-test_si_minor.ctm.sys (deflated 78%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-fusion-test_si_minor.ctm.pra (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-conv-fusion-test_si_minor.ctm.raw (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/output-hypothesis-fusion-test_si_minor.ctm (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/test/test_si_minor/out.output-hypothesis-conv-fusion-test_si_minor.ctm (deflated 80%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/ (stored 0%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/test_sd.csv (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-fusion-test_sd.ctm.sys (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-fusion-test_sd.ctm.pra (deflated 92%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/output-hypothesis-conv-fusion-test_sd.ctm (deflated 86%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-conv-fusion-test_sd.ctm.raw (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-conv-fusion-test_sd.ctm (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/test_sd_wer.txt (deflated 4%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-fusion-test_sd.ctm.sgml (deflated 92%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/tmp.stm (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/tmp2.ctm (deflated 85%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-fusion-test_sd.ctm (deflated 86%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-conv-fusion-test_sd.ctm.sgml (deflated 88%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/output-hypothesis-fusion-test_sd.ctm (deflated 88%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-conv-fusion-test_sd.ctm.pra (deflated 83%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-fusion-test_sd.ctm.raw (deflated 79%)
#   adding: work_dir/Baseline+MKR+TN/test/test_sd/out.output-hypothesis-conv-fusion-test_sd.ctm.sys (deflated 77%)
#   adding: work_dir/Baseline+MKR+TN/config.yaml (deflated 53%)

# %%
import os
from google.colab import files

print("Zipping model weights...")
# !zip -r experiment_models.zip ./work_dir/ -i "*.pt" "*.pth"

if os.path.exists('experiment_models.zip'):
    files.download('experiment_models.zip')
